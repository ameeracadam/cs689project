# %% [markdown]
# # Create influenza vaccination cumulative fact table

# %%
import pandas as pd
import numpy as np
import re
import traceback
import sys
from variables import *

# %%
df = pd.read_csv('dataset/Influenza_Vaccination_Coverage.csv')
df.head()
# Out:
#               Vaccine Geography Type  Geography  FIPS Season/Survey Year  \
# 0  Seasonal Influenza       Counties  New Haven  9009               2018
# 1  Seasonal Influenza       Counties  New Haven  9009               2021
# 2  Seasonal Influenza       Counties  New Haven  9009               2020
# 3  Seasonal Influenza       Counties  New Haven  9009               2021
# 4  Seasonal Influenza       Counties  New Haven  9009               2018
#
#    Month Dimension Type            Dimension Estimate (%)    95% CI (%)  \
# 0      1     >=18 Years  Non-Medical Setting         45.5  43.9 to 47.2
# 1      1     >=18 Years  Non-Medical Setting         53.0  46.0 to 60.9
# 2      1            Age           >=18 Years         52.4  50.6 to 54.3
# 3      1            Age           >=18 Years         50.2  45.4 to 55.8
# 4      1            Age           >=18 Years         34.0  32.6 to 35.5
#
#    Sample Size
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df.shape[0]
# Out:
# 220729

# %%
df[df['Estimate (%)'].isna()]
# Out:
# Empty DataFrame
# Columns: [Vaccine, Geography Type, Geography, FIPS, Season/Survey Year, Month, Dimension Type, Dimension, Estimate (%), 95% CI (%), Sample Size]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220729 entries, 0 to 220728
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Vaccine             220729 non-null  object
#  1   Geography Type      220729 non-null  object
#  2   Geography           220729 non-null  object
#  3   FIPS                220729 non-null  int64
#  4   Season/Survey Year  220729 non-null  object
#  5   Month               220729 non-null  int64
#  6   Dimension Type      220729 non-null  object
#  7   Dimension           220729 non-null  object
#  8   Estimate (%)        220729 non-null  object
#  9   95% CI (%)          220495 non-null  object
#  10  Sample Size         197270 non-null  float64
# dtypes: float64(1), int64(2), object(8)
# memory usage: 18.5+ MB

# %%
df['Vaccine'].unique()
# Out:
# array(['Seasonal Influenza',
#        'Any Influenza Vaccination, Seasonal or H1N1',
#        'Influenza A (H1N1) 2009 Monovalent'], dtype=object)

# %%
# the H1N1 vaccine is only in 2009-2010( H1N1 pandemic)
df['Season/Survey Year'][df['Vaccine'] == 'Influenza A (H1N1) 2009 Monovalent'].unique()
# Out:
# array(['2009-10'], dtype=object)

# %%
# and the influenza + h1n1 combi is only for 2009-2010
df['Season/Survey Year'][df['Vaccine'] == 'Any Influenza Vaccination, Seasonal or H1N1'].unique()
# Out:
# array(['2009-10'], dtype=object)

# %%
df['Season/Survey Year'][df['Vaccine'] == 'Seasonal Influenza'].unique()
# Out:
# array(['2018', '2021', '2020', '2019', '2009-10', '2020-21', '2017-18',
#        '2014-15', '2015-16', '2019-20', '2013-14', '2018-19', '2012-13',
#        '2016-17', '2011-12', '2010-11', '2021-22', '2023-24', '2022',
#        '2022-23'], dtype=object)

# %%
filled_df_nrow = df.shape[0]
filled_df_nrow
# Out:
# 220729

# %%
df['Sample Size'] = pd.to_numeric(df['Sample Size'], errors='coerce').astype('Int64')
df.head()
# Out:
#               Vaccine Geography Type  Geography  FIPS Season/Survey Year  \
# 0  Seasonal Influenza       Counties  New Haven  9009               2018
# 1  Seasonal Influenza       Counties  New Haven  9009               2021
# 2  Seasonal Influenza       Counties  New Haven  9009               2020
# 3  Seasonal Influenza       Counties  New Haven  9009               2021
# 4  Seasonal Influenza       Counties  New Haven  9009               2018
#
#    Month Dimension Type            Dimension Estimate (%)    95% CI (%)  \
# 0      1     >=18 Years  Non-Medical Setting         45.5  43.9 to 47.2
# 1      1     >=18 Years  Non-Medical Setting         53.0  46.0 to 60.9
# 2      1            Age           >=18 Years         52.4  50.6 to 54.3
# 3      1            Age           >=18 Years         50.2  45.4 to 55.8
# 4      1            Age           >=18 Years         34.0  32.6 to 35.5
#
#    Sample Size
# 0         <NA>
# 1         <NA>
# 2         <NA>
# 3         <NA>
# 4         <NA>

# %% [markdown]
# - * Estimates not reliable because sample size is <30.
# - † Estimates not reliable because relative standard error is >0.3.
# - ‡ Estimates might not be reliable because confidence interval half-width is >10
# We can discard them first

# %%
df['Estimate (%)'] = pd.to_numeric(df['Estimate (%)'], errors='coerce').astype(float)

# %%
ci = df['95% CI (%)'].astype(str).str.replace('%', '', regex=False).str.strip()
df[['ci_lower', 'ci_upper']] = ci.str.extract(r'([\d.]+)\s+to\s+([\d.]+)')
df[['ci_lower', 'ci_upper']] = ci.str.split(r'\s+to\s+', expand=True)

# %%
df.head()
# Out:
#               Vaccine Geography Type  Geography  FIPS Season/Survey Year  \
# 0  Seasonal Influenza       Counties  New Haven  9009               2018
# 1  Seasonal Influenza       Counties  New Haven  9009               2021
# 2  Seasonal Influenza       Counties  New Haven  9009               2020
# 3  Seasonal Influenza       Counties  New Haven  9009               2021
# 4  Seasonal Influenza       Counties  New Haven  9009               2018
#
#    Month Dimension Type            Dimension  Estimate (%)    95% CI (%)  \
# 0      1     >=18 Years  Non-Medical Setting          45.5  43.9 to 47.2
# 1      1     >=18 Years  Non-Medical Setting          53.0  46.0 to 60.9
# 2      1            Age           >=18 Years          52.4  50.6 to 54.3
# 3      1            Age           >=18 Years          50.2  45.4 to 55.8
# 4      1            Age           >=18 Years          34.0  32.6 to 35.5
#
#    Sample Size ci_lower ci_upper
# 0         <NA>     43.9     47.2
# 1         <NA>     46.0     60.9
# 2         <NA>     50.6     54.3
# 3         <NA>     45.4     55.8
# 4         <NA>     32.6     35.5

# %%
# getting the vaccine dimension table from postgres
import psycopg2 as pg
from creds import POSTGRES_USERNAME, POSTGRES_PW
conn = pg.connect(
    dbname='cs689_project',  
    user=POSTGRES_USERNAME,
    password=POSTGRES_PW,
    host='localhost',
    port='5432'
)
cursor = conn.cursor()

# %%
cursor.execute("SELECT vaccine_id, cleaned_vaccine, start_date, vaccine_strains FROM vaccine_dim")
mapping_data = cursor.fetchall()

vaccine_mapping = pd.DataFrame(mapping_data, columns=["vaccine_id", "cleaned_vaccine", "start_date", "vaccine_strains"])
vaccine_mapping
# Out:
#     vaccine_id                              cleaned_vaccine  start_date  \
# 0            1                                         DTaP  2011-09-01
# 1            2                                        Polio  2011-09-01
# 2            3                                        Hep B  2011-09-01
# 3            4                                          PCV  2011-09-01
# 4            7                                          Hib  2011-09-01
# 5           10                            Combined 7 Series  2011-09-01
# 6           11                                    Rotavirus  2011-09-01
# 7            9                                    Influenza  2011-09-01
# 8           12                                    Influenza  2012-09-01
# 9           13                                    Influenza  2013-09-01
# 10          14                                    Influenza  2014-09-01
# 11          15                                    Influenza  2015-09-01
# 12          16                                    Influenza  2016-09-01
# 13          17                                    Influenza  2017-09-01
# 14          18                                    Influenza  2018-09-01
# 15          19                                    Influenza  2019-09-01
# 16          20                                    Influenza  2020-09-01
# 17          21                                    Influenza  2021-09-01
# 18          22                                    Influenza  2022-09-01
# 19          23                                    Influenza  2023-09-01
# 20          25                                          HPV  2011-09-01
# 21          26                                         Tdap  2011-09-01
# 22          27                                      MenACWY  2011-09-01
# 23          28                                         HepB  2011-09-01
# 24           6                                          MMR  2011-09-01
# 25           5                                    Varicella  2011-09-01
# 26           8                                        Hep A  2011-09-01
# 27          24                                    Influenza  2024-09-01
# 28          35  Any Influenza Vaccination, Seasonal or H1N1  2009-09-01
# 29          36           Influenza A (H1N1) 2009 Monovalent  2009-09-01
# 30          34                                    Influenza  2009-09-01
# 31          37                                    Influenza  2010-09-01
#
#                                       vaccine_strains
# 0   Diphtheria, Tetanus, and Bordetella pertussis ...
# 1          Poliovirus Types 1, 2, and 3 (inactivated)
# 2                             Hepatitis B virus (HBV)
# 3   Streptococcus pneumoniae — multiple serotypes ...
# 4                       Haemophilus influenzae type b
# 5   Includes: DTaP, IPV, MMR, Hib, Hep B, Varicell...
# 6   Rotavirus types G1, G2, G3, G4, G9 (Rotarix); ...
# 7   A/California/7/2009, A/Victoria/361/2011 (H3N2...
# 8   A/California/7/2009, A/Victoria/361/2011 (H3N2...
# 9   A/California/7/2009, A/Texas/50/2012 (H3N2), B...
# 10  A/California/7/2009, A/Texas/50/2012 (H3N2), B...
# 11  A/California/7/2009, A/Switzerland/9715293/201...
# 12  A/California/7/2009, A/Hong Kong/4801/2014 (H3...
# 13  A/Michigan/45/2015, A/Hong Kong/4801/2014 (H3N...
# 14  A/Michigan/45/2015, A/Singapore/INFIMH-16-0019...
# 15  A/Brisbane/02/2018, A/Kansas/14/2017 (H3N2), B...
# 16  A/Guangdong-Maonan/SWL1536/2019, A/Hong Kong/2...
# 17  A/Victoria/2570/2019, A/Cambodia/e0826360/2020...
# 18  A/Victoria/2570/2019, A/Darwin/9/2021 (H3N2), ...
# 19  A/Victoria/4897/2022, A/Darwin/9/2021 (H3N2), ...
# 20       HPV Types: 6, 11, 16, 18, 31, 33, 45, 52, 58
# 21  No strains — protects against the toxin (tetan...
# 22  A, C, W, Y (the most common disease-causing st...
# 23                            Hepatitis B virus (HBV)
# 24          Measles virus, Mumps virus, Rubella virus
# 25                Varicella-zoster virus (chickenpox)
# 26                                  Hepatitis A virus
# 27  A/Victoria/4897/2022, A/Thailand/8/2022 (H3N2)...
# 28               A/California/7/2009 (H1N1)pdm09-like
# 29  A/Brisbane/59/2007 (H1N1)-like, A/Brisbane/10/...
# 30  A/Brisbane/59/2007 (H1N1)-like, A/Brisbane/10/...
# 31  A/California/7/2009 (H1N1)pdm09-like virus, A/...

# %%
# forming the vaccine for 2009-2011
vaccine_dim = ['Influenza', 'Any Influenza Vaccination, Seasonal or H1N1',
'Influenza A (H1N1) 2009 Monovalent']
vaccine_dim = pd.DataFrame(vaccine_dim)
vaccine_dim.columns = ['Vaccine']
vaccine_dim['vaccine_strain'] = ['A/Brisbane/59/2007 (H1N1)-like, A/Brisbane/10/2007 (H3N2), B/Brisbane/60/2008-like', 'A/California/7/2009 (H1N1)pdm09-like', 
'A/Brisbane/59/2007 (H1N1)-like, A/Brisbane/10/2007 (H3N2), A/California/7/2009 (H1N1)pdm09-like']
vaccine_dim['description'] = ['Protect against the three influenza strains anticipated to be most prevalent during the season',
'In response to the 2009 H1N1 pandemic, a separate monovalent vaccine was developed specifically to target the new H1N1 strain',
'Both influenza strains and the H1N1 monovalent vaccine']
vaccine_dim['start_datetime'] = pd.to_datetime('2009-09')
vaccine_dim['end_datetime'] = pd.to_datetime('2100-12')

# %%
vaccine_dim
# Out:
#                                        Vaccine  \
# 0                                    Influenza
# 1  Any Influenza Vaccination, Seasonal or H1N1
# 2           Influenza A (H1N1) 2009 Monovalent
#
#                                       vaccine_strain  \
# 0  A/Brisbane/59/2007 (H1N1)-like, A/Brisbane/10/...
# 1               A/California/7/2009 (H1N1)pdm09-like
# 2  A/Brisbane/59/2007 (H1N1)-like, A/Brisbane/10/...
#
#                                          description start_datetime  \
# 0  Protect against the three influenza strains an...     2009-09-01
# 1  In response to the 2009 H1N1 pandemic, a separ...     2009-09-01
# 2  Both influenza strains and the H1N1 monovalent...     2009-09-01
#
#   end_datetime
# 0   2100-12-01
# 1   2100-12-01
# 2   2100-12-01

# %%
vaccine_2011 = pd.DataFrame([{
    'Vaccine': 'Influenza',
    'description': 'Protects against seasonal flu viruses',
    'vaccine_strain': 'A/California/7/2009 (H1N1)pdm09-like virus, A/Perth/16/2009 (H3N2)-like virus, B/Brisbane/60/2008-like virus'
, 'start_datetime':pd.to_datetime('2010-09'),
'end_datetime':pd.to_datetime('2100-12')}])
vaccine_dim = pd.concat([vaccine_dim, vaccine_2011], ignore_index=True)
vaccine_dim['vaccine_name'] = ['Fluzone,Fluarix,FluLaval,Fluvirin,Afluria', 
'Fluzone, FluMist, Fluarix, FluLaval, Afluria, Fluvirin',
'Sanofi Pasteur H1N1 Monovalent, Novartis H1N1 Monovalent, CSL Limited H1N1 Monovalent, ID Biomedical H1N1 Monovalent, MedImmune H1N1 Monovalent',
'Fluzone, FluMist, Fluarix, FluLaval, Afluria, Fluvirin']
vaccine_dim
# Out:
#                                        Vaccine  \
# 0                                    Influenza
# 1  Any Influenza Vaccination, Seasonal or H1N1
# 2           Influenza A (H1N1) 2009 Monovalent
# 3                                    Influenza
#
#                                       vaccine_strain  \
# 0  A/Brisbane/59/2007 (H1N1)-like, A/Brisbane/10/...
# 1               A/California/7/2009 (H1N1)pdm09-like
# 2  A/Brisbane/59/2007 (H1N1)-like, A/Brisbane/10/...
# 3  A/California/7/2009 (H1N1)pdm09-like virus, A/...
#
#                                          description start_datetime  \
# 0  Protect against the three influenza strains an...     2009-09-01
# 1  In response to the 2009 H1N1 pandemic, a separ...     2009-09-01
# 2  Both influenza strains and the H1N1 monovalent...     2009-09-01
# 3              Protects against seasonal flu viruses     2010-09-01
#
#   end_datetime                                       vaccine_name
# 0   2100-12-01          Fluzone,Fluarix,FluLaval,Fluvirin,Afluria
# 1   2100-12-01  Fluzone, FluMist, Fluarix, FluLaval, Afluria, ...
# 2   2100-12-01  Sanofi Pasteur H1N1 Monovalent, Novartis H1N1 ...
# 3   2100-12-01  Fluzone, FluMist, Fluarix, FluLaval, Afluria, ...

# %%
def update_vaccine_dim(df_update_vaccine):
    update_query = """
    UPDATE vaccine_dim
    SET end_date     = %s - INTERVAL '1 month',
        current_flag = 'N'
    WHERE cleaned_vaccine = %s
    AND current_flag   = 'Y';
    """

    insert_query = """
    INSERT INTO vaccine_dim
    (cleaned_vaccine,
    vaccine_description,
    vaccine_strains,
    vaccine_names,
    start_date,
    end_date,
    current_flag)
    VALUES (%s, %s, %s, %s, %s, %s, %s)
    ON CONFLICT (cleaned_vaccine, start_date) DO NOTHING;
    """
    try:
        for _, row in df_update_vaccine.iterrows():
            cursor.execute(
                update_query,
                (row['start_datetime'], row['Vaccine'])
            )
            cursor.execute(
                insert_query,
                (
                    row['Vaccine'],
                    row['description'],
                    row['vaccine_strain'],
                    row['vaccine_name'],
                    row['start_datetime'],
                    row['end_datetime'],
                    'Y'
                )
            )
        conn.commit()
        print(f"{len(df_update_vaccine)} SCD2 records processed.")

    except Exception as e:
        conn.rollback()
        print("Error occurred:", e)

# %%
update_vaccine_dim(vaccine_dim)
# Out:
# 4 SCD2 records processed.

# %%
# clean the vaccines first
df['Vaccine'] = df['Vaccine'].replace('Seasonal Influenza', 'Influenza')
df.head()
# Out:
#      Vaccine Geography Type  Geography  FIPS Season/Survey Year  Month  \
# 0  Influenza       Counties  New Haven  9009               2018      1
# 1  Influenza       Counties  New Haven  9009               2021      1
# 2  Influenza       Counties  New Haven  9009               2020      1
# 3  Influenza       Counties  New Haven  9009               2021      1
# 4  Influenza       Counties  New Haven  9009               2018      1
#
#   Dimension Type            Dimension  Estimate (%)    95% CI (%)  \
# 0     >=18 Years  Non-Medical Setting          45.5  43.9 to 47.2
# 1     >=18 Years  Non-Medical Setting          53.0  46.0 to 60.9
# 2            Age           >=18 Years          52.4  50.6 to 54.3
# 3            Age           >=18 Years          50.2  45.4 to 55.8
# 4            Age           >=18 Years          34.0  32.6 to 35.5
#
#    Sample Size ci_lower ci_upper
# 0         <NA>     43.9     47.2
# 1         <NA>     46.0     60.9
# 2         <NA>     50.6     54.3
# 3         <NA>     45.4     55.8
# 4         <NA>     32.6     35.5

# %%
cursor.execute("SELECT vaccine_id, cleaned_vaccine, start_date, vaccine_strains FROM vaccine_dim")
mapping_data = cursor.fetchall()

vaccine_mapping = pd.DataFrame(mapping_data, columns=["vaccine_id", "cleaned_vaccine", "start_date", "vaccine_strains"])
vaccine_mapping
# Out:
#     vaccine_id                              cleaned_vaccine  start_date  \
# 0            1                                         DTaP  2011-09-01
# 1            2                                        Polio  2011-09-01
# 2            3                                        Hep B  2011-09-01
# 3            4                                          PCV  2011-09-01
# 4            7                                          Hib  2011-09-01
# 5           10                            Combined 7 Series  2011-09-01
# 6           11                                    Rotavirus  2011-09-01
# 7            9                                    Influenza  2011-09-01
# 8           12                                    Influenza  2012-09-01
# 9           13                                    Influenza  2013-09-01
# 10          14                                    Influenza  2014-09-01
# 11          15                                    Influenza  2015-09-01
# 12          16                                    Influenza  2016-09-01
# 13          17                                    Influenza  2017-09-01
# 14          18                                    Influenza  2018-09-01
# 15          19                                    Influenza  2019-09-01
# 16          20                                    Influenza  2020-09-01
# 17          21                                    Influenza  2021-09-01
# 18          22                                    Influenza  2022-09-01
# 19          23                                    Influenza  2023-09-01
# 20          25                                          HPV  2011-09-01
# 21          26                                         Tdap  2011-09-01
# 22          27                                      MenACWY  2011-09-01
# 23          28                                         HepB  2011-09-01
# 24           6                                          MMR  2011-09-01
# 25           5                                    Varicella  2011-09-01
# 26           8                                        Hep A  2011-09-01
# 27          24                                    Influenza  2024-09-01
# 28          34                                    Influenza  2009-09-01
# 29          37                                    Influenza  2010-09-01
# 30          35  Any Influenza Vaccination, Seasonal or H1N1  2009-09-01
# 31          36           Influenza A (H1N1) 2009 Monovalent  2009-09-01
#
#                                       vaccine_strains
# 0   Diphtheria, Tetanus, and Bordetella pertussis ...
# 1          Poliovirus Types 1, 2, and 3 (inactivated)
# 2                             Hepatitis B virus (HBV)
# 3   Streptococcus pneumoniae — multiple serotypes ...
# 4                       Haemophilus influenzae type b
# 5   Includes: DTaP, IPV, MMR, Hib, Hep B, Varicell...
# 6   Rotavirus types G1, G2, G3, G4, G9 (Rotarix); ...
# 7   A/California/7/2009, A/Victoria/361/2011 (H3N2...
# 8   A/California/7/2009, A/Victoria/361/2011 (H3N2...
# 9   A/California/7/2009, A/Texas/50/2012 (H3N2), B...
# 10  A/California/7/2009, A/Texas/50/2012 (H3N2), B...
# 11  A/California/7/2009, A/Switzerland/9715293/201...
# 12  A/California/7/2009, A/Hong Kong/4801/2014 (H3...
# 13  A/Michigan/45/2015, A/Hong Kong/4801/2014 (H3N...
# 14  A/Michigan/45/2015, A/Singapore/INFIMH-16-0019...
# 15  A/Brisbane/02/2018, A/Kansas/14/2017 (H3N2), B...
# 16  A/Guangdong-Maonan/SWL1536/2019, A/Hong Kong/2...
# 17  A/Victoria/2570/2019, A/Cambodia/e0826360/2020...
# 18  A/Victoria/2570/2019, A/Darwin/9/2021 (H3N2), ...
# 19  A/Victoria/4897/2022, A/Darwin/9/2021 (H3N2), ...
# 20       HPV Types: 6, 11, 16, 18, 31, 33, 45, 52, 58
# 21  No strains — protects against the toxin (tetan...
# 22  A, C, W, Y (the most common disease-causing st...
# 23                            Hepatitis B virus (HBV)
# 24          Measles virus, Mumps virus, Rubella virus
# 25                Varicella-zoster virus (chickenpox)
# 26                                  Hepatitis A virus
# 27  A/Victoria/4897/2022, A/Thailand/8/2022 (H3N2)...
# 28  A/Brisbane/59/2007 (H1N1)-like, A/Brisbane/10/...
# 29  A/California/7/2009 (H1N1)pdm09-like virus, A/...
# 30               A/California/7/2009 (H1N1)pdm09-like
# 31  A/Brisbane/59/2007 (H1N1)-like, A/Brisbane/10/...

# %%
vaccine_mapping['start_date'] = pd.to_datetime(vaccine_mapping['start_date'])
vaccine_mapping['year'] = vaccine_mapping['start_date'].dt.year
vaccine_mapping
# Out:
#     vaccine_id                              cleaned_vaccine start_date  \
# 0            1                                         DTaP 2011-09-01
# 1            2                                        Polio 2011-09-01
# 2            3                                        Hep B 2011-09-01
# 3            4                                          PCV 2011-09-01
# 4            7                                          Hib 2011-09-01
# 5           10                            Combined 7 Series 2011-09-01
# 6           11                                    Rotavirus 2011-09-01
# 7            9                                    Influenza 2011-09-01
# 8           12                                    Influenza 2012-09-01
# 9           13                                    Influenza 2013-09-01
# 10          14                                    Influenza 2014-09-01
# 11          15                                    Influenza 2015-09-01
# 12          16                                    Influenza 2016-09-01
# 13          17                                    Influenza 2017-09-01
# 14          18                                    Influenza 2018-09-01
# 15          19                                    Influenza 2019-09-01
# 16          20                                    Influenza 2020-09-01
# 17          21                                    Influenza 2021-09-01
# 18          22                                    Influenza 2022-09-01
# 19          23                                    Influenza 2023-09-01
# 20          25                                          HPV 2011-09-01
# 21          26                                         Tdap 2011-09-01
# 22          27                                      MenACWY 2011-09-01
# 23          28                                         HepB 2011-09-01
# 24           6                                          MMR 2011-09-01
# 25           5                                    Varicella 2011-09-01
# 26           8                                        Hep A 2011-09-01
# 27          24                                    Influenza 2024-09-01
# 28          34                                    Influenza 2009-09-01
# 29          37                                    Influenza 2010-09-01
# 30          35  Any Influenza Vaccination, Seasonal or H1N1 2009-09-01
# 31          36           Influenza A (H1N1) 2009 Monovalent 2009-09-01
#
#                                       vaccine_strains  year
# 0   Diphtheria, Tetanus, and Bordetella pertussis ...  2011
# 1          Poliovirus Types 1, 2, and 3 (inactivated)  2011
# 2                             Hepatitis B virus (HBV)  2011
# 3   Streptococcus pneumoniae — multiple serotypes ...  2011
# 4                       Haemophilus influenzae type b  2011
# 5   Includes: DTaP, IPV, MMR, Hib, Hep B, Varicell...  2011
# 6   Rotavirus types G1, G2, G3, G4, G9 (Rotarix); ...  2011
# 7   A/California/7/2009, A/Victoria/361/2011 (H3N2...  2011
# 8   A/California/7/2009, A/Victoria/361/2011 (H3N2...  2012
# 9   A/California/7/2009, A/Texas/50/2012 (H3N2), B...  2013
# 10  A/California/7/2009, A/Texas/50/2012 (H3N2), B...  2014
# 11  A/California/7/2009, A/Switzerland/9715293/201...  2015
# 12  A/California/7/2009, A/Hong Kong/4801/2014 (H3...  2016
# 13  A/Michigan/45/2015, A/Hong Kong/4801/2014 (H3N...  2017
# 14  A/Michigan/45/2015, A/Singapore/INFIMH-16-0019...  2018
# 15  A/Brisbane/02/2018, A/Kansas/14/2017 (H3N2), B...  2019
# 16  A/Guangdong-Maonan/SWL1536/2019, A/Hong Kong/2...  2020
# 17  A/Victoria/2570/2019, A/Cambodia/e0826360/2020...  2021
# 18  A/Victoria/2570/2019, A/Darwin/9/2021 (H3N2), ...  2022
# 19  A/Victoria/4897/2022, A/Darwin/9/2021 (H3N2), ...  2023
# 20       HPV Types: 6, 11, 16, 18, 31, 33, 45, 52, 58  2011
# 21  No strains — protects against the toxin (tetan...  2011
# 22  A, C, W, Y (the most common disease-causing st...  2011
# 23                            Hepatitis B virus (HBV)  2011
# 24          Measles virus, Mumps virus, Rubella virus  2011
# 25                Varicella-zoster virus (chickenpox)  2011
# 26                                  Hepatitis A virus  2011
# 27  A/Victoria/4897/2022, A/Thailand/8/2022 (H3N2)...  2024
# 28  A/Brisbane/59/2007 (H1N1)-like, A/Brisbane/10/...  2009
# 29  A/California/7/2009 (H1N1)pdm09-like virus, A/...  2010
# 30               A/California/7/2009 (H1N1)pdm09-like  2009
# 31  A/Brisbane/59/2007 (H1N1)-like, A/Brisbane/10/...  2009

# %% [markdown]
# Deal with cumulative dataset first (scoped to HHS region and state)

# %%
df_cumulative = df[df['Geography Type'] != 'Counties']
df_cumulative.head()
# Out:
#       Vaccine      Geography Type   Geography  FIPS Season/Survey Year  Month  \
# 6   Influenza  States/Local Areas  New Jersey    34            2009-10      5
# 7   Influenza  States/Local Areas  New Jersey    34            2009-10      4
# 8   Influenza  States/Local Areas  New Jersey    34            2009-10     11
# 9   Influenza  States/Local Areas  New Jersey    34            2009-10     10
# 10  Influenza  States/Local Areas  New Jersey    34            2009-10      9
#
#         Dimension Type                                       Dimension  \
# 6   Race and Ethnicity  American Indian or Alaska Native, Non-Hispanic
# 7   Race and Ethnicity  American Indian or Alaska Native, Non-Hispanic
# 8   Race and Ethnicity                             Asian, Non-Hispanic
# 9   Race and Ethnicity                             Asian, Non-Hispanic
# 10  Race and Ethnicity                             Asian, Non-Hispanic
#
#     Estimate (%)      95% CI (%)  Sample Size ci_lower ci_upper
# 6           57.7  40.2 to 75.2 ‡           48     40.2   75.2 ‡
# 7           57.7  40.2 to 75.2 ‡           48     40.2   75.2 ‡
# 8           34.7    29.1 to 40.3          552     29.1     40.3
# 9           24.8    19.7 to 29.9          552     19.7     29.9
# 10          10.8     6.6 to 15.0          552      6.6     15.0

# %%
for _, row in df_cumulative.iterrows():
    start_year = row['Season/Survey Year'][:4]
    end_year = '20' + row['Season/Survey Year'][-2:]
    df_cumulative.loc[_, 'start_cohort_year'] = start_year
    df_cumulative.loc[_, 'start_cohort_datetime'] = str(start_year) + '-' + str(row['Month'])
    df_cumulative.loc[_, 'end_cohort_datetime'] = str(end_year) + '-' + str(row['Month'])
df_cumulative
# Out:
# /var/folders/jq/q12_1s5j0kx30cqlm76w1m740000gn/T/ipykernel_5170/3261165056.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cumulative.loc[_, 'start_cohort_year'] = start_year
# /var/folders/jq/q12_1s5j0kx30cqlm76w1m740000gn/T/ipykernel_5170/3261165056.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cumulative.loc[_, 'start_cohort_datetime'] = str(start_year) + '-' + str(row['Month'])
# /var/folders/jq/q12_1s5j0kx30cqlm76w1m740000gn/T/ipykernel_5170/3261165056.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cumulative.loc[_, 'end_cohort_datetime'] = str(end_year) + '-' + str(row['Month'])
#           Vaccine      Geography Type   Geography  FIPS Season/Survey Year  \
# 6       Influenza  States/Local Areas  New Jersey    34            2009-10
# 7       Influenza  States/Local Areas  New Jersey    34            2009-10
# 8       Influenza  States/Local Areas  New Jersey    34            2009-10
# 9       Influenza  States/Local Areas  New Jersey    34            2009-10
# 10      Influenza  States/Local Areas  New Jersey    34            2009-10
# ...           ...                 ...         ...   ...                ...
# 220724  Influenza  States/Local Areas       Maine    23            2017-18
# 220725  Influenza  States/Local Areas       Maine    23            2020-21
# 220726  Influenza  States/Local Areas       Maine    23            2017-18
# 220727  Influenza  States/Local Areas       Maine    23            2020-21
# 220728  Influenza  States/Local Areas       Maine    23            2014-15
#
#         Month       Dimension Type  \
# 6           5   Race and Ethnicity
# 7           4   Race and Ethnicity
# 8          11   Race and Ethnicity
# 9          10   Race and Ethnicity
# 10          9   Race and Ethnicity
# ...       ...                  ...
# 220724      1           >=65 Years
# 220725      1           >=65 Years
# 220726      1          18-64 Years
# 220727      1          18-64 Years
# 220728      1  6 Months - 17 Years
#
#                                              Dimension  Estimate (%)  \
# 6       American Indian or Alaska Native, Non-Hispanic          57.7
# 7       American Indian or Alaska Native, Non-Hispanic          57.7
# 8                                  Asian, Non-Hispanic          34.7
# 9                                  Asian, Non-Hispanic          24.8
# 10                                 Asian, Non-Hispanic          10.8
# ...                                                ...           ...
# 220724                             Non-Medical Setting          41.4
# 220725                             Non-Medical Setting          30.0
# 220726                             Non-Medical Setting          45.6
# 220727                             Non-Medical Setting          33.7
# 220728                                          School          20.3
#
#             95% CI (%)  Sample Size ci_lower ci_upper start_cohort_year  \
# 6       40.2 to 75.2 ‡           48     40.2   75.2 ‡              2009
# 7       40.2 to 75.2 ‡           48     40.2   75.2 ‡              2009
# 8         29.1 to 40.3          552     29.1     40.3              2009
# 9         19.7 to 29.9          552     19.7     29.9              2009
# 10         6.6 to 15.0          552      6.6     15.0              2009
# ...                ...          ...      ...      ...               ...
# 220724    36.8 to 46.0         <NA>     36.8     46.0              2017
# 220725    26.6 to 33.4         2064     26.6     33.4              2020
# 220726    39.7 to 51.5         <NA>     39.7     51.5              2017
# 220727    29.7 to 37.7         2772     29.7     37.7              2020
# 220728    15.5 to 25.1          211     15.5     25.1              2014
#
#        start_cohort_datetime end_cohort_datetime
# 6                     2009-5              2010-5
# 7                     2009-4              2010-4
# 8                    2009-11             2010-11
# 9                    2009-10             2010-10
# 10                    2009-9              2010-9
# ...                      ...                 ...
# 220724                2017-1              2018-1
# 220725                2020-1              2021-1
# 220726                2017-1              2018-1
# 220727                2020-1              2021-1
# 220728                2014-1              2015-1
#
# [198911 rows x 16 columns]

# %%
df_cumulative['start_cohort_year'] = (pd.to_numeric(df_cumulative['start_cohort_year'], errors='coerce').astype('Int64'))
df_cumulative = pd.merge(df_cumulative, vaccine_mapping, left_on = ['Vaccine', 'start_cohort_year'], right_on=['cleaned_vaccine', 'year'], how='left')
df_cumulative.head()
# Out:
# /var/folders/jq/q12_1s5j0kx30cqlm76w1m740000gn/T/ipykernel_5170/1721538295.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cumulative['start_cohort_year'] = (pd.to_numeric(df_cumulative['start_cohort_year'], errors='coerce').astype('Int64'))
#      Vaccine      Geography Type   Geography  FIPS Season/Survey Year  Month  \
# 0  Influenza  States/Local Areas  New Jersey    34            2009-10      5
# 1  Influenza  States/Local Areas  New Jersey    34            2009-10      4
# 2  Influenza  States/Local Areas  New Jersey    34            2009-10     11
# 3  Influenza  States/Local Areas  New Jersey    34            2009-10     10
# 4  Influenza  States/Local Areas  New Jersey    34            2009-10      9
#
#        Dimension Type                                       Dimension  \
# 0  Race and Ethnicity  American Indian or Alaska Native, Non-Hispanic
# 1  Race and Ethnicity  American Indian or Alaska Native, Non-Hispanic
# 2  Race and Ethnicity                             Asian, Non-Hispanic
# 3  Race and Ethnicity                             Asian, Non-Hispanic
# 4  Race and Ethnicity                             Asian, Non-Hispanic
#
#    Estimate (%)      95% CI (%)  ...  ci_lower ci_upper start_cohort_year  \
# 0          57.7  40.2 to 75.2 ‡  ...      40.2   75.2 ‡              2009
# 1          57.7  40.2 to 75.2 ‡  ...      40.2   75.2 ‡              2009
# 2          34.7    29.1 to 40.3  ...      29.1     40.3              2009
# 3          24.8    19.7 to 29.9  ...      19.7     29.9              2009
# 4          10.8     6.6 to 15.0  ...       6.6     15.0              2009
#
#    start_cohort_datetime end_cohort_datetime vaccine_id  cleaned_vaccine  \
# 0                 2009-5              2010-5         34        Influenza
# 1                 2009-4              2010-4         34        Influenza
# 2                2009-11             2010-11         34        Influenza
# 3                2009-10             2010-10         34        Influenza
# 4                 2009-9              2010-9         34        Influenza
#
#   start_date                                    vaccine_strains  year
# 0 2009-09-01  A/Brisbane/59/2007 (H1N1)-like, A/Brisbane/10/...  2009
# 1 2009-09-01  A/Brisbane/59/2007 (H1N1)-like, A/Brisbane/10/...  2009
# 2 2009-09-01  A/Brisbane/59/2007 (H1N1)-like, A/Brisbane/10/...  2009
# 3 2009-09-01  A/Brisbane/59/2007 (H1N1)-like, A/Brisbane/10/...  2009
# 4 2009-09-01  A/Brisbane/59/2007 (H1N1)-like, A/Brisbane/10/...  2009
#
# [5 rows x 21 columns]

# %%
df_cumulative.head()
# Out:
#      Vaccine      Geography Type   Geography  FIPS Season/Survey Year  Month  \
# 0  Influenza  States/Local Areas  New Jersey    34            2009-10      5
# 1  Influenza  States/Local Areas  New Jersey    34            2009-10      4
# 2  Influenza  States/Local Areas  New Jersey    34            2009-10     11
# 3  Influenza  States/Local Areas  New Jersey    34            2009-10     10
# 4  Influenza  States/Local Areas  New Jersey    34            2009-10      9
#
#        Dimension Type                                       Dimension  \
# 0  Race and Ethnicity  American Indian or Alaska Native, Non-Hispanic
# 1  Race and Ethnicity  American Indian or Alaska Native, Non-Hispanic
# 2  Race and Ethnicity                             Asian, Non-Hispanic
# 3  Race and Ethnicity                             Asian, Non-Hispanic
# 4  Race and Ethnicity                             Asian, Non-Hispanic
#
#    Estimate (%)      95% CI (%)  ...  ci_lower ci_upper start_cohort_year  \
# 0          57.7  40.2 to 75.2 ‡  ...      40.2   75.2 ‡              2009
# 1          57.7  40.2 to 75.2 ‡  ...      40.2   75.2 ‡              2009
# 2          34.7    29.1 to 40.3  ...      29.1     40.3              2009
# 3          24.8    19.7 to 29.9  ...      19.7     29.9              2009
# 4          10.8     6.6 to 15.0  ...       6.6     15.0              2009
#
#    start_cohort_datetime end_cohort_datetime vaccine_id  cleaned_vaccine  \
# 0                 2009-5              2010-5         34        Influenza
# 1                 2009-4              2010-4         34        Influenza
# 2                2009-11             2010-11         34        Influenza
# 3                2009-10             2010-10         34        Influenza
# 4                 2009-9              2010-9         34        Influenza
#
#   start_date                                    vaccine_strains  year
# 0 2009-09-01  A/Brisbane/59/2007 (H1N1)-like, A/Brisbane/10/...  2009
# 1 2009-09-01  A/Brisbane/59/2007 (H1N1)-like, A/Brisbane/10/...  2009
# 2 2009-09-01  A/Brisbane/59/2007 (H1N1)-like, A/Brisbane/10/...  2009
# 3 2009-09-01  A/Brisbane/59/2007 (H1N1)-like, A/Brisbane/10/...  2009
# 4 2009-09-01  A/Brisbane/59/2007 (H1N1)-like, A/Brisbane/10/...  2009
#
# [5 rows x 21 columns]

# %%
df_cumulative[df_cumulative['vaccine_id'].isna()]
# Out:
# Empty DataFrame
# Columns: [Vaccine, Geography Type, Geography, FIPS, Season/Survey Year, Month, Dimension Type, Dimension, Estimate (%), 95% CI (%), Sample Size, ci_lower, ci_upper, start_cohort_year, start_cohort_datetime, end_cohort_datetime, vaccine_id, cleaned_vaccine, start_date, vaccine_strains, year]
# Index: []
#
# [0 rows x 21 columns]

# %%
df_cumulative.drop(columns=['Vaccine', 'cleaned_vaccine','vaccine_strains', 'year', 'start_date', 'Season/Survey Year', 'start_cohort_year', 'Month', '95% CI (%)'], inplace=True)
df_cumulative.head()
# Out:
#        Geography Type   Geography  FIPS      Dimension Type  \
# 0  States/Local Areas  New Jersey    34  Race and Ethnicity
# 1  States/Local Areas  New Jersey    34  Race and Ethnicity
# 2  States/Local Areas  New Jersey    34  Race and Ethnicity
# 3  States/Local Areas  New Jersey    34  Race and Ethnicity
# 4  States/Local Areas  New Jersey    34  Race and Ethnicity
#
#                                         Dimension  Estimate (%)  Sample Size  \
# 0  American Indian or Alaska Native, Non-Hispanic          57.7           48
# 1  American Indian or Alaska Native, Non-Hispanic          57.7           48
# 2                             Asian, Non-Hispanic          34.7          552
# 3                             Asian, Non-Hispanic          24.8          552
# 4                             Asian, Non-Hispanic          10.8          552
#
#   ci_lower ci_upper start_cohort_datetime end_cohort_datetime  vaccine_id
# 0     40.2   75.2 ‡                2009-5              2010-5          34
# 1     40.2   75.2 ‡                2009-4              2010-4          34
# 2     29.1     40.3               2009-11             2010-11          34
# 3     19.7     29.9               2009-10             2010-10          34
# 4      6.6     15.0                2009-9              2010-9          34

# %%
df_cumulative['start_cohort_datetime'] = pd.to_datetime(df_cumulative['start_cohort_datetime']).dt.strftime('%Y-%m-%d')
df_cumulative['end_cohort_datetime'] = pd.to_datetime(df_cumulative['end_cohort_datetime']).dt.strftime('%Y-%m-%d')

# %%
df_cumulative.head()
# Out:
#        Geography Type   Geography  FIPS      Dimension Type  \
# 0  States/Local Areas  New Jersey    34  Race and Ethnicity
# 1  States/Local Areas  New Jersey    34  Race and Ethnicity
# 2  States/Local Areas  New Jersey    34  Race and Ethnicity
# 3  States/Local Areas  New Jersey    34  Race and Ethnicity
# 4  States/Local Areas  New Jersey    34  Race and Ethnicity
#
#                                         Dimension  Estimate (%)  Sample Size  \
# 0  American Indian or Alaska Native, Non-Hispanic          57.7           48
# 1  American Indian or Alaska Native, Non-Hispanic          57.7           48
# 2                             Asian, Non-Hispanic          34.7          552
# 3                             Asian, Non-Hispanic          24.8          552
# 4                             Asian, Non-Hispanic          10.8          552
#
#   ci_lower ci_upper start_cohort_datetime end_cohort_datetime  vaccine_id
# 0     40.2   75.2 ‡                2009-5              2010-5          34
# 1     40.2   75.2 ‡                2009-4              2010-4          34
# 2     29.1     40.3               2009-11             2010-11          34
# 3     19.7     29.9               2009-10             2010-10          34
# 4      6.6     15.0                2009-9              2010-9          34

# %%
cursor.execute("SELECT geography_id, original_geography, original_geography_type FROM geography_dim")
mapping_data = cursor.fetchall()

geography_mapping = pd.DataFrame(mapping_data, columns=["geography_id", "original_geography", "original_geography_type"])
geography_mapping
# Out:
#     geography_id original_geography original_geography_type
# 0              4           Region 7    HHS Regions/National
# 1              7           Region 1    HHS Regions/National
# 2              8           Region 8    HHS Regions/National
# 3              3          Region 10    HHS Regions/National
# 4              1           Region 6    HHS Regions/National
# ..           ...                ...                     ...
# 75            55           Maryland      States/Local Areas
# 76            58   NY-Rest of state      States/Local Areas
# 77            12       North Dakota      States/Local Areas
# 78            77   TX-Dallas County      States/Local Areas
# 79            76  TX-El Paso County      States/Local Areas
#
# [80 rows x 3 columns]

# %%
df_cumulative = pd.merge(df_cumulative, geography_mapping, left_on = ['Geography', 'Geography Type'], right_on=['original_geography', 'original_geography_type'], how='left')
df_cumulative.head()
# Out:
#        Geography Type   Geography  FIPS      Dimension Type  \
# 0  States/Local Areas  New Jersey    34  Race and Ethnicity
# 1  States/Local Areas  New Jersey    34  Race and Ethnicity
# 2  States/Local Areas  New Jersey    34  Race and Ethnicity
# 3  States/Local Areas  New Jersey    34  Race and Ethnicity
# 4  States/Local Areas  New Jersey    34  Race and Ethnicity
#
#                                         Dimension  Estimate (%)  Sample Size  \
# 0  American Indian or Alaska Native, Non-Hispanic          57.7           48
# 1  American Indian or Alaska Native, Non-Hispanic          57.7           48
# 2                             Asian, Non-Hispanic          34.7          552
# 3                             Asian, Non-Hispanic          24.8          552
# 4                             Asian, Non-Hispanic          10.8          552
#
#   ci_lower ci_upper start_cohort_datetime end_cohort_datetime  vaccine_id  \
# 0     40.2   75.2 ‡                2009-5              2010-5          34
# 1     40.2   75.2 ‡                2009-4              2010-4          34
# 2     29.1     40.3               2009-11             2010-11          34
# 3     19.7     29.9               2009-10             2010-10          34
# 4      6.6     15.0                2009-9              2010-9          34
#
#    geography_id original_geography original_geography_type
# 0            14         New Jersey      States/Local Areas
# 1            14         New Jersey      States/Local Areas
# 2            14         New Jersey      States/Local Areas
# 3            14         New Jersey      States/Local Areas
# 4            14         New Jersey      States/Local Areas

# %%
df_cumulative.drop(columns=['Geography', 'Geography Type', 'original_geography', 'original_geography_type'], inplace=True)
df_cumulative.head()
# Out:
#    FIPS      Dimension Type                                       Dimension  \
# 0    34  Race and Ethnicity  American Indian or Alaska Native, Non-Hispanic
# 1    34  Race and Ethnicity  American Indian or Alaska Native, Non-Hispanic
# 2    34  Race and Ethnicity                             Asian, Non-Hispanic
# 3    34  Race and Ethnicity                             Asian, Non-Hispanic
# 4    34  Race and Ethnicity                             Asian, Non-Hispanic
#
#    Estimate (%)  Sample Size ci_lower ci_upper start_cohort_datetime  \
# 0          57.7           48     40.2   75.2 ‡                2009-5
# 1          57.7           48     40.2   75.2 ‡                2009-4
# 2          34.7          552     29.1     40.3               2009-11
# 3          24.8          552     19.7     29.9               2009-10
# 4          10.8          552      6.6     15.0                2009-9
#
#   end_cohort_datetime  vaccine_id  geography_id
# 0              2010-5          34            14
# 1              2010-4          34            14
# 2             2010-11          34            14
# 3             2010-10          34            14
# 4              2010-9          34            14

# %%
df_race = df_cumulative[df_cumulative['Dimension Type'] == 'Race and Ethnicity']
df_race.head()
# Out:
#    FIPS      Dimension Type                                       Dimension  \
# 0    34  Race and Ethnicity  American Indian or Alaska Native, Non-Hispanic
# 1    34  Race and Ethnicity  American Indian or Alaska Native, Non-Hispanic
# 2    34  Race and Ethnicity                             Asian, Non-Hispanic
# 3    34  Race and Ethnicity                             Asian, Non-Hispanic
# 4    34  Race and Ethnicity                             Asian, Non-Hispanic
#
#    Estimate (%)  Sample Size ci_lower ci_upper start_cohort_datetime  \
# 0          57.7           48     40.2   75.2 ‡                2009-5
# 1          57.7           48     40.2   75.2 ‡                2009-4
# 2          34.7          552     29.1     40.3               2009-11
# 3          24.8          552     19.7     29.9               2009-10
# 4          10.8          552      6.6     15.0                2009-9
#
#   end_cohort_datetime  vaccine_id  geography_id
# 0              2010-5          34            14
# 1              2010-4          34            14
# 2             2010-11          34            14
# 3             2010-10          34            14
# 4              2010-9          34            14

# %%
cursor.execute("SELECT race_ethnicity, race_ethnicity_id FROM race_ethnicity_dim")
mapping_data = cursor.fetchall()

race_ethnicity_mapping = pd.DataFrame(mapping_data, columns=["race_ethnicity", "race_ethnicity_id"])
race_ethnicity_mapping
# Out:
#                                    race_ethnicity  race_ethnicity_id
# 0  American Indian or Alaska Native, Non-Hispanic                  5
# 1                             Asian, Non-Hispanic                  6
# 2                             White, Non-Hispanic                  2
# 3                                        Hispanic                  3
# 4           Other or Multiple Races, Non-Hispanic                  1
# 5                             Black, Non-Hispanic                  4

# %%
race_dim = df_race['Dimension'].unique()
race_dim
# form into a dataframe
race_dim = pd.DataFrame(race_dim)
race_dim.columns = ['Race and Ethnicity']
race_dim = race_dim.reset_index(drop=True)
race_dim['id'] = race_dim.index + 1
display(race_dim)
# Out:
#                                Race and Ethnicity  id
# 0  American Indian or Alaska Native, Non-Hispanic   1
# 1                             Asian, Non-Hispanic   2
# 2                             White, Non-Hispanic   3
# 3                                        Hispanic   4
# 4           Other or Multiple Races, Non-Hispanic   5
# 5                             Black, Non-Hispanic   6

# %%
try:
    insert_query = '''
    INSERT INTO race_ethnicity_dim (
        race_ethnicity
    )
    VALUES (%s)
    ON CONFLICT (race_ethnicity) 
    DO UPDATE SET
        race_ethnicity = EXCLUDED.race_ethnicity;
    '''
    for index, row in race_dim.iterrows():
        print(row['Race and Ethnicity'])
        cursor.execute(insert_query, (row['Race and Ethnicity'],))
    conn.commit()
    print(f"{len(race_dim)} records inserted into race_dim.")

except Exception as e:
    print(f"Error occurred: {e}")
    conn.rollback()
# Out:
# American Indian or Alaska Native, Non-Hispanic
# Asian, Non-Hispanic
# White, Non-Hispanic
# Hispanic
# Other or Multiple Races, Non-Hispanic
# Black, Non-Hispanic
# 6 records inserted into race_dim.

# %%
cursor.execute("SELECT race_ethnicity, race_ethnicity_id FROM race_ethnicity_dim")
mapping_data = cursor.fetchall()

race_ethnicity_mapping = pd.DataFrame(mapping_data, columns=["race_ethnicity", "race_ethnicity_id"])
race_ethnicity_mapping
# Out:
#                                    race_ethnicity  race_ethnicity_id
# 0  American Indian or Alaska Native, Non-Hispanic                  5
# 1                             Asian, Non-Hispanic                  6
# 2                             White, Non-Hispanic                  2
# 3                                        Hispanic                  3
# 4           Other or Multiple Races, Non-Hispanic                  1
# 5                             Black, Non-Hispanic                  4

# %%
df_race = pd.merge(df_race, race_ethnicity_mapping, left_on = ['Dimension'], right_on=['race_ethnicity'], how='left')
df_race.head()
# Out:
#    FIPS      Dimension Type                                       Dimension  \
# 0    34  Race and Ethnicity  American Indian or Alaska Native, Non-Hispanic
# 1    34  Race and Ethnicity  American Indian or Alaska Native, Non-Hispanic
# 2    34  Race and Ethnicity                             Asian, Non-Hispanic
# 3    34  Race and Ethnicity                             Asian, Non-Hispanic
# 4    34  Race and Ethnicity                             Asian, Non-Hispanic
#
#    Estimate (%)  Sample Size ci_lower ci_upper start_cohort_datetime  \
# 0          57.7           48     40.2   75.2 ‡                2009-5
# 1          57.7           48     40.2   75.2 ‡                2009-4
# 2          34.7          552     29.1     40.3               2009-11
# 3          24.8          552     19.7     29.9               2009-10
# 4          10.8          552      6.6     15.0                2009-9
#
#   end_cohort_datetime  vaccine_id  geography_id  \
# 0              2010-5          34            14
# 1              2010-4          34            14
# 2             2010-11          34            14
# 3             2010-10          34            14
# 4              2010-9          34            14
#
#                                    race_ethnicity  race_ethnicity_id
# 0  American Indian or Alaska Native, Non-Hispanic                  5
# 1  American Indian or Alaska Native, Non-Hispanic                  5
# 2                             Asian, Non-Hispanic                  6
# 3                             Asian, Non-Hispanic                  6
# 4                             Asian, Non-Hispanic                  6

# %%
df_race.drop(columns=['Dimension Type', 'Dimension', 'race_ethnicity'], inplace=True)
df_race.head()
# Out:
#    FIPS  Estimate (%)  Sample Size ci_lower ci_upper start_cohort_datetime  \
# 0    34          57.7           48     40.2   75.2 ‡                2009-5
# 1    34          57.7           48     40.2   75.2 ‡                2009-4
# 2    34          34.7          552     29.1     40.3               2009-11
# 3    34          24.8          552     19.7     29.9               2009-10
# 4    34          10.8          552      6.6     15.0                2009-9
#
#   end_cohort_datetime  vaccine_id  geography_id  race_ethnicity_id
# 0              2010-5          34            14                  5
# 1              2010-4          34            14                  5
# 2             2010-11          34            14                  6
# 3             2010-10          34            14                  6
# 4              2010-9          34            14                  6

# %%
df_age = df_cumulative[df_cumulative['Dimension Type'] == 'Age']
df_age.head()
# Out:
#     FIPS Dimension Type   Dimension  Estimate (%)  Sample Size ci_lower  \
# 13    34            Age  >=65 Years          65.2         2554     62.5
# 14    34            Age  >=65 Years          65.2         2554     62.5
# 15    34            Age  >=65 Years          65.1         2554     62.4
# 16    34            Age  >=65 Years          64.4         2554     61.7
# 17    34            Age  >=65 Years          63.8         2554     61.1
#
#    ci_upper start_cohort_datetime end_cohort_datetime  vaccine_id  \
# 13     67.9                2009-5              2010-5          34
# 14     67.9                2009-4              2010-4          34
# 15     67.8                2009-3              2010-3          34
# 16     67.1                2009-2              2010-2          34
# 17     66.5                2009-1              2010-1          34
#
#     geography_id
# 13            14
# 14            14
# 15            14
# 16            14
# 17            14

# %%
# do the same thing as what we did in the transactional
df_age.rename(columns={'Dimension': 'Age'}, inplace=True)
df_age.drop(columns=['Dimension Type'], inplace=True)
print(df_age.shape[0])
df_age.head()
# Out:
# 148036
# /var/folders/jq/q12_1s5j0kx30cqlm76w1m740000gn/T/ipykernel_3733/13825907.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_age.rename(columns={'Dimension': 'Age'}, inplace=True)
# /var/folders/jq/q12_1s5j0kx30cqlm76w1m740000gn/T/ipykernel_3733/13825907.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_age.drop(columns=['Dimension Type'], inplace=True)
#     FIPS         Age  Estimate (%)  Sample Size ci_lower ci_upper  \
# 13    34  >=65 Years          65.2         2554     62.5     67.9
# 14    34  >=65 Years          65.2         2554     62.5     67.9
# 15    34  >=65 Years          65.1         2554     62.4     67.8
# 16    34  >=65 Years          64.4         2554     61.7     67.1
# 17    34  >=65 Years          63.8         2554     61.1     66.5
#
#    start_cohort_datetime end_cohort_datetime  vaccine_id  geography_id
# 13                2009-5              2010-5          34            14
# 14                2009-4              2010-4          34            14
# 15                2009-3              2010-3          34            14
# 16                2009-2              2010-2          34            14
# 17                2009-1              2010-1          34            14

# %%
df_location = df_cumulative[~df_cumulative['Dimension Type'].isin(['Race and Ethnicity', 'Age'])]
df_location.rename(columns={'Dimension Type': 'Age', 'Dimension':'vaccine_location'}, inplace=True)
df_location.head()
# Out:
# /var/folders/jq/q12_1s5j0kx30cqlm76w1m740000gn/T/ipykernel_3733/1502862343.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_location.rename(columns={'Dimension Type': 'Age', 'Dimension':'vaccine_location'}, inplace=True)
#      FIPS                  Age     vaccine_location  Estimate (%)  \
# 66     34           >=18 Years  Non-Medical Setting          53.7
# 118    34           >=18 Years  Non-Medical Setting          42.4
# 131    34  6 Months - 17 Years  Non-Medical Setting           3.4
# 132    34          18-49 Years  Non-Medical Setting          49.4
# 133    34  6 Months - 17 Years  Non-Medical Setting           8.8
#
#      Sample Size ci_lower ci_upper start_cohort_datetime end_cohort_datetime  \
# 66          3285     49.6     57.8                2020-1              2021-1
# 118         <NA>     36.3     48.5                2017-1              2018-1
# 131           51      2.2      4.6                2014-1              2015-1
# 132         <NA>     37.3     61.5                2017-1              2018-1
# 133         1814      7.0     11.1                2020-1              2021-1
#
#      vaccine_id  geography_id
# 66           20            14
# 118          17            14
# 131          14            14
# 132          17            14
# 133          20            14

# %%
vaccine_location_dim = df_location['vaccine_location'].unique()
vaccine_location_dim = pd.DataFrame(vaccine_location_dim)
vaccine_location_dim.columns = ['vaccine_location']
vaccine_location_dim = vaccine_location_dim.reset_index(drop=True)
display(vaccine_location_dim)
# Out:
#       vaccine_location
# 0  Non-Medical Setting
# 1               School
# 2       Pharmacy/Store
# 3            Workplace
# 4      Medical Setting

# %%
try:
    insert_query = '''
    INSERT INTO vaccine_location_dim (
        vaccine_location
    )
    VALUES (%s);
    '''
    for index, row in vaccine_location_dim.iterrows():
        print(row['vaccine_location'])
        cursor.execute(insert_query, (row['vaccine_location'],))
    conn.commit()
    print(f"{len(vaccine_location_dim)} records inserted into vaccine_location_dim.")

except Exception as e:
    print(f"Error occurred: {e}")
    conn.rollback()
# Out:
# Non-Medical Setting
# Error occurred: duplicate key value violates unique constraint "unique_vaccine_location_dim"
# DETAIL:  Key (vaccine_location)=(Non-Medical Setting) already exists.

# %%
cursor.execute("SELECT vaccine_location, vaccine_location_id FROM vaccine_location_dim")
mapping_data = cursor.fetchall()

vac_location = pd.DataFrame(mapping_data, columns=["vaccine_location", "vaccine_location_id"])
vac_location
# Out:
#       vaccine_location  vaccine_location_id
# 0  Non-Medical Setting                    1
# 1               School                    2
# 2       Pharmacy/Store                    3
# 3            Workplace                    4
# 4      Medical Setting                    5

# %%
# we merge with the vaccine_dim
df_location = pd.merge(df_location, vac_location, left_on = ['vaccine_location'], right_on=['vaccine_location'], how='left')
df_location.head()
# Out:
#    FIPS                  Age     vaccine_location  Estimate (%)  Sample Size  \
# 0    34           >=18 Years  Non-Medical Setting          53.7         3285
# 1    34           >=18 Years  Non-Medical Setting          42.4         <NA>
# 2    34  6 Months - 17 Years  Non-Medical Setting           3.4           51
# 3    34          18-49 Years  Non-Medical Setting          49.4         <NA>
# 4    34  6 Months - 17 Years  Non-Medical Setting           8.8         1814
#
#   ci_lower ci_upper start_cohort_datetime end_cohort_datetime  vaccine_id  \
# 0     49.6     57.8                2020-1              2021-1          20
# 1     36.3     48.5                2017-1              2018-1          17
# 2      2.2      4.6                2014-1              2015-1          14
# 3     37.3     61.5                2017-1              2018-1          17
# 4      7.0     11.1                2020-1              2021-1          20
#
#    geography_id  vaccine_location_id
# 0            14                    1
# 1            14                    1
# 2            14                    1
# 3            14                    1
# 4            14                    1

# %%
df_location.drop(columns=['vaccine_location'], inplace=True)
df_location.head()
# Out:
#    FIPS                  Age  Estimate (%)  Sample Size ci_lower ci_upper  \
# 0    34           >=18 Years          53.7         3285     49.6     57.8
# 1    34           >=18 Years          42.4         <NA>     36.3     48.5
# 2    34  6 Months - 17 Years           3.4           51      2.2      4.6
# 3    34          18-49 Years          49.4         <NA>     37.3     61.5
# 4    34  6 Months - 17 Years           8.8         1814      7.0     11.1
#
#   start_cohort_datetime end_cohort_datetime  vaccine_id  geography_id  \
# 0                2020-1              2021-1          20            14
# 1                2017-1              2018-1          17            14
# 2                2014-1              2015-1          14            14
# 3                2017-1              2018-1          17            14
# 4                2020-1              2021-1          20            14
#
#    vaccine_location_id
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
df_cumulative_dimension = pd.concat([df_age, df_race, df_location])
df_cumulative_dimension.head()
# Out:
#     FIPS         Age  Estimate (%)  Sample Size ci_lower ci_upper  \
# 13    34  >=65 Years          65.2         2554     62.5     67.9
# 14    34  >=65 Years          65.2         2554     62.5     67.9
# 15    34  >=65 Years          65.1         2554     62.4     67.8
# 16    34  >=65 Years          64.4         2554     61.7     67.1
# 17    34  >=65 Years          63.8         2554     61.1     66.5
#
#    start_cohort_datetime end_cohort_datetime  vaccine_id  geography_id  \
# 13                2009-5              2010-5          34            14
# 14                2009-4              2010-4          34            14
# 15                2009-3              2010-3          34            14
# 16                2009-2              2010-2          34            14
# 17                2009-1              2010-1          34            14
#
#     race_ethnicity_id  vaccine_location_id
# 13                NaN                  NaN
# 14                NaN                  NaN
# 15                NaN                  NaN
# 16                NaN                  NaN
# 17                NaN                  NaN

# %%
df_cumulative_dimension.shape[0]
# Out:
# 198911

# %%
df_cumulative.shape[0]
# Out:
# 198911

# %%
df_cumulative_dimension.head()
# Out:
#     FIPS         Age  Estimate (%)  Sample Size ci_lower ci_upper  \
# 13    34  >=65 Years          65.2         2554     62.5     67.9
# 14    34  >=65 Years          65.2         2554     62.5     67.9
# 15    34  >=65 Years          65.1         2554     62.4     67.8
# 16    34  >=65 Years          64.4         2554     61.7     67.1
# 17    34  >=65 Years          63.8         2554     61.1     66.5
#
#    start_cohort_datetime end_cohort_datetime  vaccine_id  geography_id  \
# 13                2009-5              2010-5          34            14
# 14                2009-4              2010-4          34            14
# 15                2009-3              2010-3          34            14
# 16                2009-2              2010-2          34            14
# 17                2009-1              2010-1          34            14
#
#     race_ethnicity_id  vaccine_location_id
# 13                NaN                  NaN
# 14                NaN                  NaN
# 15                NaN                  NaN
# 16                NaN                  NaN
# 17                NaN                  NaN

# %%
df_cumulative_dimension.columns
# Out:
# Index(['FIPS', 'Age', 'Estimate (%)', 'Sample Size', 'ci_lower', 'ci_upper',
#        'start_cohort_datetime', 'end_cohort_datetime', 'vaccine_id',
#        'geography_id', 'race_ethnicity_id', 'vaccine_location_id'],
#       dtype='object')

# %%
df['Dimension Type'].unique()
# Out:
# array(['>=18 Years', 'Age', 'Race and Ethnicity', '6 Months - 17 Years',
#        '18-49 Years', '>=65 Years', '50-64 Years', '18-64 Years'],
#       dtype=object)

# %%
age_groups = ['>=18 Years', '6 Months - 17 Years', '18-49 Years', '>=65 Years', '50-64 Years', '18-64 Years']
df_age = df[df['Dimension Type'].isin(age_groups)]
df_age.head()
# Out:
#        Vaccine      Geography Type   Geography  FIPS Season/Survey Year  \
# 0    Influenza            Counties   New Haven  9009               2018
# 1    Influenza            Counties   New Haven  9009               2021
# 72   Influenza  States/Local Areas  New Jersey    34            2020-21
# 124  Influenza  States/Local Areas  New Jersey    34            2017-18
# 137  Influenza  States/Local Areas  New Jersey    34            2014-15
#
#      Month       Dimension Type            Dimension Estimate (%)  \
# 0        1           >=18 Years  Non-Medical Setting         45.5
# 1        1           >=18 Years  Non-Medical Setting         53.0
# 72       1           >=18 Years  Non-Medical Setting         53.7
# 124      1           >=18 Years  Non-Medical Setting         42.4
# 137      1  6 Months - 17 Years  Non-Medical Setting          3.4
#
#        95% CI (%)  Sample Size ci_lower ci_upper
# 0    43.9 to 47.2         <NA>     43.9     47.2
# 1    46.0 to 60.9         <NA>     46.0     60.9
# 72   49.6 to 57.8         3285     49.6     57.8
# 124  36.3 to 48.5         <NA>     36.3     48.5
# 137    2.2 to 4.6           51      2.2      4.6

# %%
df_age['Dimension'].unique()
# Out:
# array(['Non-Medical Setting', 'School', 'Pharmacy/Store', 'Workplace',
#        'Medical Setting'], dtype=object)

# %%
df_cumulative_dimension.shape[0]
# Out:
# 198911

# %%
df_cumulative_dimension.head()
# Out:
#     FIPS         Age  Estimate (%)  Sample Size ci_lower ci_upper  \
# 13    34  >=65 Years          65.2         2554     62.5     67.9
# 14    34  >=65 Years          65.2         2554     62.5     67.9
# 15    34  >=65 Years          65.1         2554     62.4     67.8
# 16    34  >=65 Years          64.4         2554     61.7     67.1
# 17    34  >=65 Years          63.8         2554     61.1     66.5
#
#    start_cohort_datetime end_cohort_datetime  vaccine_id  geography_id  \
# 13            2009-05-01          2010-05-01          34            14
# 14            2009-04-01          2010-04-01          34            14
# 15            2009-03-01          2010-03-01          34            14
# 16            2009-02-01          2010-02-01          34            14
# 17            2009-01-01          2010-01-01          34            14
#
#     race_ethnicity_id  vaccine_location_id
# 13                NaN                  NaN
# 14                NaN                  NaN
# 15                NaN                  NaN
# 16                NaN                  NaN
# 17                NaN                  NaN

# %%
df_cumulative_dimension.columns
# Out:
# Index(['FIPS', 'Age', 'Estimate (%)', 'Sample Size', 'ci_lower', 'ci_upper',
#        'start_cohort_datetime', 'end_cohort_datetime', 'vaccine_id',
#        'geography_id', 'race_ethnicity_id', 'vaccine_location_id'],
#       dtype='object')

# %%
df_cumulative_dimension['ci_lower'] = pd.to_numeric(df['ci_lower'], errors='coerce').astype(float)
df_cumulative_dimension['ci_upper'] = pd.to_numeric(df['ci_upper'], errors='coerce').astype(float)

# %%
df_cumulative_dimension['ci_lower'] = df_cumulative_dimension['ci_lower'].fillna(0)
df_cumulative_dimension['ci_upper'] = df_cumulative_dimension['ci_upper'].fillna(0)
df_cumulative_dimension['Estimate (%)'] = df_cumulative_dimension['Estimate (%)'].fillna(0)

# %%
df_cumulative_dimension['ci_lower']
# Out:
# 13      40.2
# 14      36.7
# 15      24.8
# 16       0.0
# 17      40.2
#         ...
# 3075    40.3
# 3076    45.3
# 3077    48.2
# 3078     0.4
# 3079     2.6
# Name: ci_lower, Length: 198911, dtype: float64

# %%
# loading cumulative fact table
try:
    insert_query='''
    INSERT INTO influenza_cumulative_fact_test(
        age,
        influenza_cumulative_estimate_pct,
        influenza_cumulative_sample_size,
        influenza_cumulative_ci_lower,
        influenza_cumulative_ci_upper,
        influenza_cumulative_start_cohort_datetime,
        influenza_cumulative_end_cohort_datetime,
        influenza_cumulative_vaccine_id,
        influenza_cumulative_geography_id,
        influenza_cumulative_race_ethnicity_id,
        influenza_cumulative_vaccine_location_id
    )
    VALUES(%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
    '''
    for index, row in df_cumulative_dimension.iterrows():
        start_cohort_date = pd.to_datetime(row['start_cohort_datetime']).date() if pd.notnull(row['start_cohort_datetime']) else None
        end_cohort_date = pd.to_datetime(row['end_cohort_datetime']).date() if pd.notnull(row['end_cohort_datetime']) else None
        vaccine_id = int(row['vaccine_id']) if pd.notnull(row['vaccine_id']) else None
        geography_id = int(row['geography_id']) if pd.notnull(row['geography_id']) else None
        race_ethnicity_id = int(row['race_ethnicity_id']) if pd.notnull(row['race_ethnicity_id']) else None
        sample_size = int(row['Sample Size']) if pd.notnull(row['Sample Size']) else None
        vaccine_location_id = int(row['vaccine_location_id']) if pd.notnull(row['vaccine_location_id']) else None

        cursor.execute(insert_query,(
        row['Age'],
        row['Estimate (%)'],
        sample_size,
        row['ci_lower'],
        row['ci_upper'],
        start_cohort_date,
        end_cohort_date,
        vaccine_id,
        geography_id,
        race_ethnicity_id,
        vaccine_location_id 
        ))
    conn.commit()
    print(f"{len(df_cumulative_dimension)} records inserted into influenza_cumulative_fact.")

except Exception as e:
    print(f"Error occurred: {e}")
    traceback.print_exc(file=sys.stdout)
    conn.rollback()
# Out:
# 198911 records inserted into influenza_cumulative_fact.
