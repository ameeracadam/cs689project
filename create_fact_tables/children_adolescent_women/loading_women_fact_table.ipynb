# %% [markdown]
# # Loading women dataset into fact tables

# %%
import pandas as pd
import numpy as np
import re
import traceback
import sys
from variables import *

# %%
df_women = pd.read_csv('dataset/Vaccination_Coverage_among_Pregnant_Women.csv')
df_women.head()
# Out:
#      Vaccine Geography Type Geography  Survey Year/Influenza Season  \
# 0  Influenza         States  Oklahoma                          2021
# 1  Influenza         States  Oklahoma                          2021
# 2  Influenza         States  Oklahoma                          2021
# 3  Influenza         States  Oklahoma                          2021
# 4       Tdap         States  Oklahoma                          2021
#
#        Dimension Type                              Dimension Estimate (%)  \
# 0  Race and Ethnicity                    White, Non-Hispanic         45.2
# 1  Race and Ethnicity                    Black, Non-Hispanic         34.1
# 2  Race and Ethnicity                               Hispanic         53.4
# 3  Race and Ethnicity  Other or Multiple Races, Non-Hispanic         51.0
# 4  Race and Ethnicity                    White, Non-Hispanic         64.9
#
#      95% CI (%)  Sample Size
# 0  38.5 to 52.0        232.0
# 1  28.7 to 39.8        299.0
# 2  48.2 to 58.5        378.0
# 3  45.2 to 56.8        501.0
# 4  57.9 to 71.4        220.0

# %%
df_women['Vaccine'].unique()
# Out:
# array(['Influenza', 'Tdap'], dtype=object)

# %% [markdown]
# Dropping the tables with empty values for critical measures. These don't provide useful insights in the analysis.

# %%
length_na_rows = len(df_women[df_women['Sample Size'].isna()])
percentage_rows_dropped = (length_na_rows/df_women.shape[0]) * 100
print(f"{percentage_rows_dropped}% contained NA fields in measures. Dropping {len(df_women[df_women['Sample Size'].isna()])} rows.")
# Out:
# 4.835348061692372% contained NA fields in measures. Dropping 232 rows.

# %%
len_df_women = df_women.shape[0]
len_df_women
# Out:
# 4798

# %%
critical_measures = ['Estimate (%)', 'Sample Size', '95% CI (%)']
df_women = df_women.dropna(subset=critical_measures)
df_women[df_women['Sample Size'].isna()]
# Out:
# Empty DataFrame
# Columns: [Vaccine, Geography Type, Geography, Survey Year/Influenza Season, Dimension Type, Dimension, Estimate (%), 95% CI (%), Sample Size]
# Index: []

# %%
filled_df_nrow = df_women.shape[0]
filled_df_nrow
# Out:
# 4566

# %%
# there is a NR* field in the estimate
# this indicates that the estimate is unreliable
# for now, we can set then to None
df_women['95% CI (%)'] = df_women['95% CI (%)'].replace('NR*', None)
df_women['Estimate (%)'] = df_women['Estimate (%)'].replace('NR*', None)

# %%
len_df_women = df_women.shape[0]
len_df_women
# Out:
# 4566

# %% [markdown]
# We see that the dataset only contains individual years. This means that the dataset are all transactions. We can load them into a transaction snapshot fact table.

# %%
# they are all transactions
df_women['Survey Year/Influenza Season'].unique()
# Out:
# array([2021, 2014, 2015, 2013, 2018, 2016, 2017, 2022, 2012, 2019, 2020])

# %% [markdown]
# Convert the `Sample Size` column to int64. This makes sense as Sample Size would refer to individual humans.

# %%
df_women['Sample Size'] = pd.to_numeric(df_women['Sample Size'], errors='coerce').astype('Int64')
df_women.head()
# Out:
#      Vaccine Geography Type Geography  Survey Year/Influenza Season  \
# 0  Influenza         States  Oklahoma                          2021
# 1  Influenza         States  Oklahoma                          2021
# 2  Influenza         States  Oklahoma                          2021
# 3  Influenza         States  Oklahoma                          2021
# 4       Tdap         States  Oklahoma                          2021
#
#        Dimension Type                              Dimension Estimate (%)  \
# 0  Race and Ethnicity                    White, Non-Hispanic         45.2
# 1  Race and Ethnicity                    Black, Non-Hispanic         34.1
# 2  Race and Ethnicity                               Hispanic         53.4
# 3  Race and Ethnicity  Other or Multiple Races, Non-Hispanic         51.0
# 4  Race and Ethnicity                    White, Non-Hispanic         64.9
#
#      95% CI (%)  Sample Size
# 0  38.5 to 52.0          232
# 1  28.7 to 39.8          299
# 2  48.2 to 58.5          378
# 3  45.2 to 56.8          501
# 4  57.9 to 71.4          220

# %%
# fill in missing dimensions
df_women['Dose'] = '1 Dose Only'

df_women.head()
# Out:
#      Vaccine Geography Type Geography  Survey Year/Influenza Season  \
# 0  Influenza         States  Oklahoma                          2021
# 1  Influenza         States  Oklahoma                          2021
# 2  Influenza         States  Oklahoma                          2021
# 3  Influenza         States  Oklahoma                          2021
# 4       Tdap         States  Oklahoma                          2021
#
#        Dimension Type                              Dimension Estimate (%)  \
# 0  Race and Ethnicity                    White, Non-Hispanic         45.2
# 1  Race and Ethnicity                    Black, Non-Hispanic         34.1
# 2  Race and Ethnicity                               Hispanic         53.4
# 3  Race and Ethnicity  Other or Multiple Races, Non-Hispanic         51.0
# 4  Race and Ethnicity                    White, Non-Hispanic         64.9
#
#      95% CI (%)  Sample Size         Dose
# 0  38.5 to 52.0          232  1 Dose Only
# 1  28.7 to 39.8          299  1 Dose Only
# 2  48.2 to 58.5          378  1 Dose Only
# 3  45.2 to 56.8          501  1 Dose Only
# 4  57.9 to 71.4          220  1 Dose Only

# %%
# checking the survey year
df_women['Survey Year/Influenza Season'].unique()
# Out:
# array([2021, 2014, 2015, 2013, 2018, 2016, 2017, 2022, 2012, 2019, 2020])

# %%
# splitting the confidence intervals
ci = df_women['95% CI (%)'].astype(str)
bounds = ci.str.split(r'\s+to\s+', expand=True)
df_women['ci_lower'] = pd.to_numeric(bounds[0], errors='coerce')
df_women['ci_upper'] = pd.to_numeric(bounds[1], errors='coerce')
df_women['ci_lower'] = df_women['ci_lower'].where(df_women['ci_lower'].notnull(), None)
df_women['ci_upper'] = df_women['ci_upper'].where(df_women['ci_upper'].notnull(), None)

# %%
# getting the vaccine dimension table from postgres
import psycopg2 as pg
from creds import POSTGRES_USERNAME, POSTGRES_PW
conn = pg.connect(
    dbname='cs689_project',  
    user=POSTGRES_USERNAME,
    password=POSTGRES_PW,
    host='localhost',
    port='5432'
)
cursor = conn.cursor()

# %% [markdown]
# Getting the vaccine dimension table from DB

# %%
cursor.execute("SELECT vaccine_id, cleaned_vaccine, start_date FROM vaccine_dim")
mapping_data = cursor.fetchall()

vaccine_mapping = pd.DataFrame(mapping_data, columns=["vaccine_id", "cleaned_vaccine", "start_date"])
vaccine_mapping
# Out:
#     vaccine_id                              cleaned_vaccine  start_date
# 0            1                                         DTaP  2011-09-01
# 1            2                                        Polio  2011-09-01
# 2            3                                        Hep B  2011-09-01
# 3            4                                          PCV  2011-09-01
# 4            7                                          Hib  2011-09-01
# 5           10                            Combined 7 Series  2011-09-01
# 6           11                                    Rotavirus  2011-09-01
# 7            9                                    Influenza  2011-09-01
# 8           12                                    Influenza  2012-09-01
# 9           13                                    Influenza  2013-09-01
# 10          14                                    Influenza  2014-09-01
# 11          15                                    Influenza  2015-09-01
# 12          16                                    Influenza  2016-09-01
# 13          17                                    Influenza  2017-09-01
# 14          18                                    Influenza  2018-09-01
# 15          19                                    Influenza  2019-09-01
# 16          20                                    Influenza  2020-09-01
# 17          21                                    Influenza  2021-09-01
# 18          22                                    Influenza  2022-09-01
# 19          23                                    Influenza  2023-09-01
# 20          25                                          HPV  2011-09-01
# 21          26                                         Tdap  2011-09-01
# 22          27                                      MenACWY  2011-09-01
# 23          28                                         HepB  2011-09-01
# 24           6                                          MMR  2011-09-01
# 25           5                                    Varicella  2011-09-01
# 26           8                                        Hep A  2011-09-01
# 27          24                                    Influenza  2024-09-01
# 28          35  Any Influenza Vaccination, Seasonal or H1N1  2009-09-01
# 29          36           Influenza A (H1N1) 2009 Monovalent  2009-09-01
# 30          34                                    Influenza  2009-09-01
# 31          37                                    Influenza  2010-09-01

# %%
vaccine_mapping['start_date'] = pd.to_datetime(vaccine_mapping['start_date'])
vaccine_mapping['year'] = vaccine_mapping['start_date'].dt.year
vaccine_mapping
# Out:
#     vaccine_id                              cleaned_vaccine start_date  year
# 0            1                                         DTaP 2011-09-01  2011
# 1            2                                        Polio 2011-09-01  2011
# 2            3                                        Hep B 2011-09-01  2011
# 3            4                                          PCV 2011-09-01  2011
# 4            7                                          Hib 2011-09-01  2011
# 5           10                            Combined 7 Series 2011-09-01  2011
# 6           11                                    Rotavirus 2011-09-01  2011
# 7            9                                    Influenza 2011-09-01  2011
# 8           12                                    Influenza 2012-09-01  2012
# 9           13                                    Influenza 2013-09-01  2013
# 10          14                                    Influenza 2014-09-01  2014
# 11          15                                    Influenza 2015-09-01  2015
# 12          16                                    Influenza 2016-09-01  2016
# 13          17                                    Influenza 2017-09-01  2017
# 14          18                                    Influenza 2018-09-01  2018
# 15          19                                    Influenza 2019-09-01  2019
# 16          20                                    Influenza 2020-09-01  2020
# 17          21                                    Influenza 2021-09-01  2021
# 18          22                                    Influenza 2022-09-01  2022
# 19          23                                    Influenza 2023-09-01  2023
# 20          25                                          HPV 2011-09-01  2011
# 21          26                                         Tdap 2011-09-01  2011
# 22          27                                      MenACWY 2011-09-01  2011
# 23          28                                         HepB 2011-09-01  2011
# 24           6                                          MMR 2011-09-01  2011
# 25           5                                    Varicella 2011-09-01  2011
# 26           8                                        Hep A 2011-09-01  2011
# 27          24                                    Influenza 2024-09-01  2024
# 28          35  Any Influenza Vaccination, Seasonal or H1N1 2009-09-01  2009
# 29          36           Influenza A (H1N1) 2009 Monovalent 2009-09-01  2009
# 30          34                                    Influenza 2009-09-01  2009
# 31          37                                    Influenza 2010-09-01  2010

# %% [markdown]
# For the flu vaccine, we have to map it to the year as the flu vaccine gets updated every year, meaning that we have to map the correct vaccine version to the correct year.

# %%
# for influenza, we need to match it to the year
years = df_women['Survey Year/Influenza Season'].astype(str).str[:4]
df_women['vaccine_year'] = np.where(df_women['Vaccine'] == 'Influenza',years,'2011')

# %%
df_women.head()
# Out:
#      Vaccine Geography Type Geography  Survey Year/Influenza Season  \
# 0  Influenza         States  Oklahoma                          2021
# 1  Influenza         States  Oklahoma                          2021
# 2  Influenza         States  Oklahoma                          2021
# 3  Influenza         States  Oklahoma                          2021
# 4       Tdap         States  Oklahoma                          2021
#
#        Dimension Type                              Dimension Estimate (%)  \
# 0  Race and Ethnicity                    White, Non-Hispanic         45.2
# 1  Race and Ethnicity                    Black, Non-Hispanic         34.1
# 2  Race and Ethnicity                               Hispanic         53.4
# 3  Race and Ethnicity  Other or Multiple Races, Non-Hispanic         51.0
# 4  Race and Ethnicity                    White, Non-Hispanic         64.9
#
#      95% CI (%)  Sample Size         Dose  ci_lower  ci_upper vaccine_year
# 0  38.5 to 52.0          232  1 Dose Only      38.5      52.0         2021
# 1  28.7 to 39.8          299  1 Dose Only      28.7      39.8         2021
# 2  48.2 to 58.5          378  1 Dose Only      48.2      58.5         2021
# 3  45.2 to 56.8          501  1 Dose Only      45.2      56.8         2021
# 4  57.9 to 71.4          220  1 Dose Only      57.9      71.4         2011

# %%
df_women[df_women['vaccine_year'].isna()]
df_women['vaccine_year'] = (pd.to_numeric(df_women['vaccine_year'], errors='coerce').astype('Int64'))

# %%
# we merge df_women with the vaccine_dim
df_women = pd.merge(df_women, vaccine_mapping, left_on = ['Vaccine', 'vaccine_year'], right_on=['cleaned_vaccine', 'year'], how='left')
df_women.head()
# Out:
#      Vaccine Geography Type Geography  Survey Year/Influenza Season  \
# 0  Influenza         States  Oklahoma                          2021
# 1  Influenza         States  Oklahoma                          2021
# 2  Influenza         States  Oklahoma                          2021
# 3  Influenza         States  Oklahoma                          2021
# 4       Tdap         States  Oklahoma                          2021
#
#        Dimension Type                              Dimension Estimate (%)  \
# 0  Race and Ethnicity                    White, Non-Hispanic         45.2
# 1  Race and Ethnicity                    Black, Non-Hispanic         34.1
# 2  Race and Ethnicity                               Hispanic         53.4
# 3  Race and Ethnicity  Other or Multiple Races, Non-Hispanic         51.0
# 4  Race and Ethnicity                    White, Non-Hispanic         64.9
#
#      95% CI (%)  Sample Size         Dose  ci_lower  ci_upper  vaccine_year  \
# 0  38.5 to 52.0          232  1 Dose Only      38.5      52.0          2021
# 1  28.7 to 39.8          299  1 Dose Only      28.7      39.8          2021
# 2  48.2 to 58.5          378  1 Dose Only      48.2      58.5          2021
# 3  45.2 to 56.8          501  1 Dose Only      45.2      56.8          2021
# 4  57.9 to 71.4          220  1 Dose Only      57.9      71.4          2011
#
#    vaccine_id cleaned_vaccine start_date  year
# 0          21       Influenza 2021-09-01  2021
# 1          21       Influenza 2021-09-01  2021
# 2          21       Influenza 2021-09-01  2021
# 3          21       Influenza 2021-09-01  2021
# 4          26            Tdap 2011-09-01  2011

# %%
df_women['vaccine_id'].unique()
# Out:
# array([21, 26, 14, 15, 13, 18, 16, 17, 22, 12, 20, 19])

# %%
df_women[df_women['vaccine_id'].isna()]
# Out:
# Empty DataFrame
# Columns: [Vaccine, Geography Type, Geography, Survey Year/Influenza Season, Dimension Type, Dimension, Estimate (%), 95% CI (%), Sample Size, Dose, ci_lower, ci_upper, vaccine_year, vaccine_id, cleaned_vaccine, start_date, year]
# Index: []

# %% [markdown]
# Data Quality check: Verify that the number of rows after the merge matches the original number of rows in the loaded dataset (after dropping empty rows)
#
# This ensures that we are not missing out any rows when performing the merges

# %%
def check_rows(df, len_df_women = filled_df_nrow):
    if df.shape[0] != len_df_women:
        print("Rows don't match!")
    else:
        print("Rows match!")

check_rows(df_women, len_df_women)
# Out:
# Rows match!

# %% [markdown]
# Mapping `Dose` to the `dose_id` in the dose dimension table

# %%
cursor.execute("SELECT dose, dose_id FROM dose_dim")
mapping_data = cursor.fetchall()

dose_mapping = pd.DataFrame(mapping_data, columns=["dose", "dose_id"])
dose_mapping
# Out:
#                                                  dose  dose_id
# 0                                            ≥3 Doses        1
# 1                                            ≥2 Doses        2
# 2                                             ≥1 Dose        3
# 3                                      ≥1 Dose, 2 Day        4
# 4                                         Full Series        5
# 5                                         1 Dose Only        6
# 6                                      Primary Series        7
# 7                                            ≥4 Doses        8
# 8                                              7 Dose        9
# 9                                      ≥1 Dose, 1 Day       10
# 10                        ≥1 Dose, 3 Day (Birth Dose)       11
# 11                                       ≥1 Dose Tdap       13
# 12                                 ≥1 Dose Td or Tdap       14
# 13                                         Up-to-Date       15
# 14                                            ≥3 Dose       16
# 15                                            ≥2 Dose       17
# 16                     ≥2 Doses or history of disease       18
# 17                   ≥2 Doses with no disease history       19
# 18                    ≥1 Dose with no disease history       20
# 19                                 History of disease       21
# 20  Series Completion (3 Dose) Among HPV Vaccinati...       24

# %%
# we merge df_women with the dose_dim
df_women = pd.merge(df_women, dose_mapping, left_on = ['Dose'], right_on=['dose'], how='left')
df_women.head()
# Out:
#      Vaccine Geography Type Geography  Survey Year/Influenza Season  \
# 0  Influenza         States  Oklahoma                          2021
# 1  Influenza         States  Oklahoma                          2021
# 2  Influenza         States  Oklahoma                          2021
# 3  Influenza         States  Oklahoma                          2021
# 4       Tdap         States  Oklahoma                          2021
#
#        Dimension Type                              Dimension Estimate (%)  \
# 0  Race and Ethnicity                    White, Non-Hispanic         45.2
# 1  Race and Ethnicity                    Black, Non-Hispanic         34.1
# 2  Race and Ethnicity                               Hispanic         53.4
# 3  Race and Ethnicity  Other or Multiple Races, Non-Hispanic         51.0
# 4  Race and Ethnicity                    White, Non-Hispanic         64.9
#
#      95% CI (%)  Sample Size         Dose  ci_lower  ci_upper  vaccine_year  \
# 0  38.5 to 52.0          232  1 Dose Only      38.5      52.0          2021
# 1  28.7 to 39.8          299  1 Dose Only      28.7      39.8          2021
# 2  48.2 to 58.5          378  1 Dose Only      48.2      58.5          2021
# 3  45.2 to 56.8          501  1 Dose Only      45.2      56.8          2021
# 4  57.9 to 71.4          220  1 Dose Only      57.9      71.4          2011
#
#    vaccine_id cleaned_vaccine start_date  year         dose  dose_id
# 0          21       Influenza 2021-09-01  2021  1 Dose Only        6
# 1          21       Influenza 2021-09-01  2021  1 Dose Only        6
# 2          21       Influenza 2021-09-01  2021  1 Dose Only        6
# 3          21       Influenza 2021-09-01  2021  1 Dose Only        6
# 4          26            Tdap 2011-09-01  2011  1 Dose Only        6

# %%
# drop original columns
df_women.drop(columns=['Vaccine', 'vaccine_year', 'cleaned_vaccine', 'Dose', 'dose', 'start_date', 'year'], inplace=True)
check_rows(df_women)
df_women.head()
# Out:
# Rows match!
#   Geography Type Geography  Survey Year/Influenza Season      Dimension Type  \
# 0         States  Oklahoma                          2021  Race and Ethnicity
# 1         States  Oklahoma                          2021  Race and Ethnicity
# 2         States  Oklahoma                          2021  Race and Ethnicity
# 3         States  Oklahoma                          2021  Race and Ethnicity
# 4         States  Oklahoma                          2021  Race and Ethnicity
#
#                                Dimension Estimate (%)    95% CI (%)  \
# 0                    White, Non-Hispanic         45.2  38.5 to 52.0
# 1                    Black, Non-Hispanic         34.1  28.7 to 39.8
# 2                               Hispanic         53.4  48.2 to 58.5
# 3  Other or Multiple Races, Non-Hispanic         51.0  45.2 to 56.8
# 4                    White, Non-Hispanic         64.9  57.9 to 71.4
#
#    Sample Size  ci_lower  ci_upper  vaccine_id  dose_id
# 0          232      38.5      52.0          21        6
# 1          299      28.7      39.8          21        6
# 2          378      48.2      58.5          21        6
# 3          501      45.2      56.8          21        6
# 4          220      57.9      71.4          26        6

# %% [markdown]
# Mapping `geography` to the geography dimension table

# %%
df_women[df_women['Geography Type'] == 'National']
# Out:
#      Geography Type      Geography  Survey Year/Influenza Season  \
# 1051       National  United States                          2022
# 1052       National  United States                          2022
# 1053       National  United States                          2022
# 1054       National  United States                          2022
# 1055       National  United States                          2022
# ...             ...            ...                           ...
# 3745       National  United States                          2015
# 3746       National  United States                          2012
# 3747       National  United States                          2018
# 3748       National  United States                          2020
# 3749       National  United States                          2019
#
#           Dimension Type            Dimension Estimate (%)    95% CI (%)  \
# 1051                 Age          18-24 Years         45.1  43.0 to 47.2
# 1052                 Age          25-34 Years         56.8  55.7 to 57.9
# 1053                 Age           >=35 Years         62.5  60.7 to 64.3
# 1054  Race and Ethnicity  White, Non-Hispanic         56.1  54.9 to 57.3
# 1055  Race and Ethnicity  Black, Non-Hispanic         42.2  39.6 to 44.8
# ...                  ...                  ...          ...           ...
# 3745                 Age          25-34 Years         54.5  52.7 to 56.3
# 3746                 Age           >=35 Years         15.7  12.7 to 19.1
# 3747  Race and Ethnicity  White, Non-Hispanic         77.6  76.5 to 78.7
# 3748  Race and Ethnicity  White, Non-Hispanic         80.4  79.3 to 81.4
# 3749  Race and Ethnicity  White, Non-Hispanic         80.1  79.0 to 81.2
#
#       Sample Size  ci_lower  ci_upper  vaccine_id  dose_id
# 1051         5769      43.0      47.2          22        6
# 1052        17853      55.7      57.9          22        6
# 1053         6733      60.7      64.3          22        6
# 1054        12992      54.9      57.3          22        6
# 1055         4336      39.6      44.8          22        6
# ...           ...       ...       ...         ...      ...
# 3745         7654      52.7      56.3          26        6
# 3746         1197      12.7      19.1          26        6
# 3747        10959      76.5      78.7          26        6
# 3748         9757      79.3      81.4          26        6
# 3749        11702      79.0      81.2          26        6
#
# [176 rows x 12 columns]

# %%
# Since the Geography Type is the same as the children and adolescents, we can rename them to make it uniform
df_women.loc[df_women['Geography Type'] == 'National', 'Geography Type'] = 'HHS Regions/National'
df_women.loc[df_women['Geography Type'] == 'States', 'Geography Type'] = 'States/Local Areas'
df_women.head()
# Out:
#        Geography Type Geography  Survey Year/Influenza Season  \
# 0  States/Local Areas  Oklahoma                          2021
# 1  States/Local Areas  Oklahoma                          2021
# 2  States/Local Areas  Oklahoma                          2021
# 3  States/Local Areas  Oklahoma                          2021
# 4  States/Local Areas  Oklahoma                          2021
#
#        Dimension Type                              Dimension Estimate (%)  \
# 0  Race and Ethnicity                    White, Non-Hispanic         45.2
# 1  Race and Ethnicity                    Black, Non-Hispanic         34.1
# 2  Race and Ethnicity                               Hispanic         53.4
# 3  Race and Ethnicity  Other or Multiple Races, Non-Hispanic         51.0
# 4  Race and Ethnicity                    White, Non-Hispanic         64.9
#
#      95% CI (%)  Sample Size  ci_lower  ci_upper  vaccine_id  dose_id
# 0  38.5 to 52.0          232      38.5      52.0          21        6
# 1  28.7 to 39.8          299      28.7      39.8          21        6
# 2  48.2 to 58.5          378      48.2      58.5          21        6
# 3  45.2 to 56.8          501      45.2      56.8          21        6
# 4  57.9 to 71.4          220      57.9      71.4          26        6

# %%
regions = df_women['Geography'][df_women['Geography Type'] == 'HHS Regions/National'].unique()
regions
# Out:
# array(['United States'], dtype=object)

# %% [markdown]
# There is an additional terriroty included: Commonwealth of the Northern Mariana Islands
# We need to add that into the dimension table

# %%
df_women['Geography'].unique()
# Out:
# array(['Oklahoma', 'Indiana', 'Nebraska', 'Missouri', 'Illinois',
#        'Minnesota', 'Oregon', 'New York', 'Vermont', 'Colorado',
#        'Maryland', 'Wyoming', 'West Virginia', 'Maine', 'Alabama',
#        'Tennessee', 'United States', 'Puerto Rico', 'Montana',
#        'Wisconsin', 'Texas', 'New Mexico', 'Alaska', 'Virginia',
#        'NY-Rest of state', 'Kentucky', 'District of Columbia',
#        'Massachusetts', 'Michigan', 'Pennsylvania', 'North Dakota',
#        'Florida', 'New Hampshire', 'Ohio', 'Arizona', 'Rhode Island',
#        'North Carolina', 'Hawaii', 'Iowa', 'Kansas', 'Connecticut',
#        'Georgia', 'Delaware', 'Louisiana',
#        'Commonwealth of the Northern Mariana Islands', 'South Dakota',
#        'Washington', 'Utah', 'New Jersey', 'Mississippi',
#        'NY-City of New York', 'Arkansas'], dtype=object)

# %%
# we fill in the regions into geography_dim
geography_dim = pd.DataFrame(columns = ['state_territory', 'municipality', 'county', 'region'])
for region in regions[1:]:
    new_row = pd.DataFrame([{'state_territory': None, 'municipality': None, 'county': None, 'region': region, 'Geography Type': 'HHS Regions/National', 'Geography':region}])
    geography_dim = pd.concat([geography_dim, new_row], ignore_index=True)

geography_dim
# Out:
# Empty DataFrame
# Columns: [state_territory, municipality, county, region]
# Index: []

# %%
# we fill in the states/local areas into geography_dim
for i in df_women['Geography'][df_women['Geography Type'] == 'States/Local Areas'].unique():
    matched = False
    if i in state_territory:
        region = state_to_region.get(i)
        new_row = pd.DataFrame([{'state_territory': i, 'municipality': None, 'county': None, 'region':'Region ' + str(region), 'Geography Type': 'States/Local Areas', 'Geography':i}])
        geography_dim = pd.concat([geography_dim, new_row], ignore_index=True)
        matched = True
    if i[0:2] in state_territory.values():
        state = str([k for k, v in state_territory.items() if v == i[0:2]][0])
        if 'County' in i:
            # i is a county
            county = str(i[3:])
            new_row = pd.DataFrame([{'state_territory': state, 'municipality': None, 'county': county, 'region':'Region ' + str(region), 'Geography Type': 'States/Local Areas', 'Geography':i}])
            geography_dim = pd.concat([geography_dim, new_row], ignore_index=True)
            matched = True
        else:
            # we assume it is a municipality
            municipality = i[3:]
            new_row = pd.DataFrame([{'state_territory': state, 'municipality': municipality, 'county': None, 'region':'Region ' + str(region), 'Geography Type': 'States/Local Areas', 'Geography':i}])
            geography_dim = pd.concat([geography_dim, new_row], ignore_index=True)
            matched = True
    if not matched:
        print(f"Unknown state or local area: {i}")

# %%
geography_dim
# Out:
#                                  state_territory      municipality county  \
# 0                                       Oklahoma              None   None
# 1                                        Indiana              None   None
# 2                                       Nebraska              None   None
# 3                                       Missouri              None   None
# 4                                       Illinois              None   None
# 5                                      Minnesota              None   None
# 6                                         Oregon              None   None
# 7                                       New York              None   None
# 8                                        Vermont              None   None
# 9                                       Colorado              None   None
# 10                                      Maryland              None   None
# 11                                       Wyoming              None   None
# 12                                 West Virginia              None   None
# 13                                         Maine              None   None
# 14                                       Alabama              None   None
# 15                                     Tennessee              None   None
# 16                                   Puerto Rico              None   None
# 17                                       Montana              None   None
# 18                                     Wisconsin              None   None
# 19                                         Texas              None   None
# 20                                    New Mexico              None   None
# 21                                        Alaska              None   None
# 22                                      Virginia              None   None
# 23                                      New York     Rest of state   None
# 24                                      Kentucky              None   None
# 25                          District of Columbia              None   None
# 26                                 Massachusetts              None   None
# 27                                      Michigan              None   None
# 28                                  Pennsylvania              None   None
# 29                                  North Dakota              None   None
# 30                                       Florida              None   None
# 31                                 New Hampshire              None   None
# 32                                          Ohio              None   None
# 33                                       Arizona              None   None
# 34                                  Rhode Island              None   None
# 35                                North Carolina              None   None
# 36                                        Hawaii              None   None
# 37                                          Iowa              None   None
# 38                                        Kansas              None   None
# 39                                   Connecticut              None   None
# 40                                       Georgia              None   None
# 41                                      Delaware              None   None
# 42                                     Louisiana              None   None
# 43  Commonwealth of the Northern Mariana Islands              None   None
# 44                                  South Dakota              None   None
# 45                                    Washington              None   None
# 46                                          Utah              None   None
# 47                                    New Jersey              None   None
# 48                                   Mississippi              None   None
# 49                                      New York  City of New York   None
# 50                                      Arkansas              None   None
#
#        region      Geography Type  \
# 0    Region 6  States/Local Areas
# 1    Region 5  States/Local Areas
# 2    Region 7  States/Local Areas
# 3    Region 7  States/Local Areas
# 4    Region 5  States/Local Areas
# 5    Region 5  States/Local Areas
# 6   Region 10  States/Local Areas
# 7    Region 2  States/Local Areas
# 8    Region 1  States/Local Areas
# 9    Region 8  States/Local Areas
# 10   Region 3  States/Local Areas
# 11   Region 8  States/Local Areas
# 12   Region 3  States/Local Areas
# 13   Region 1  States/Local Areas
# 14   Region 4  States/Local Areas
# 15   Region 4  States/Local Areas
# 16   Region 2  States/Local Areas
# 17   Region 8  States/Local Areas
# 18   Region 5  States/Local Areas
# 19   Region 6  States/Local Areas
# 20   Region 6  States/Local Areas
# 21  Region 10  States/Local Areas
# 22   Region 3  States/Local Areas
# 23   Region 3  States/Local Areas
# 24   Region 4  States/Local Areas
# 25   Region 3  States/Local Areas
# 26   Region 1  States/Local Areas
# 27   Region 5  States/Local Areas
# 28   Region 3  States/Local Areas
# 29   Region 8  States/Local Areas
# 30   Region 4  States/Local Areas
# 31   Region 1  States/Local Areas
# 32   Region 5  States/Local Areas
# 33   Region 9  States/Local Areas
# 34   Region 1  States/Local Areas
# 35   Region 4  States/Local Areas
# 36   Region 9  States/Local Areas
# 37   Region 7  States/Local Areas
# 38   Region 7  States/Local Areas
# 39   Region 1  States/Local Areas
# 40   Region 4  States/Local Areas
# 41   Region 3  States/Local Areas
# 42   Region 6  States/Local Areas
# 43   Region 9  States/Local Areas
# 44   Region 8  States/Local Areas
# 45  Region 10  States/Local Areas
# 46   Region 8  States/Local Areas
# 47   Region 2  States/Local Areas
# 48   Region 4  States/Local Areas
# 49   Region 4  States/Local Areas
# 50   Region 6  States/Local Areas
#
#                                        Geography
# 0                                       Oklahoma
# 1                                        Indiana
# 2                                       Nebraska
# 3                                       Missouri
# 4                                       Illinois
# 5                                      Minnesota
# 6                                         Oregon
# 7                                       New York
# 8                                        Vermont
# 9                                       Colorado
# 10                                      Maryland
# 11                                       Wyoming
# 12                                 West Virginia
# 13                                         Maine
# 14                                       Alabama
# 15                                     Tennessee
# 16                                   Puerto Rico
# 17                                       Montana
# 18                                     Wisconsin
# 19                                         Texas
# 20                                    New Mexico
# 21                                        Alaska
# 22                                      Virginia
# 23                              NY-Rest of state
# 24                                      Kentucky
# 25                          District of Columbia
# 26                                 Massachusetts
# 27                                      Michigan
# 28                                  Pennsylvania
# 29                                  North Dakota
# 30                                       Florida
# 31                                 New Hampshire
# 32                                          Ohio
# 33                                       Arizona
# 34                                  Rhode Island
# 35                                North Carolina
# 36                                        Hawaii
# 37                                          Iowa
# 38                                        Kansas
# 39                                   Connecticut
# 40                                       Georgia
# 41                                      Delaware
# 42                                     Louisiana
# 43  Commonwealth of the Northern Mariana Islands
# 44                                  South Dakota
# 45                                    Washington
# 46                                          Utah
# 47                                    New Jersey
# 48                                   Mississippi
# 49                           NY-City of New York
# 50                                      Arkansas

# %%
try:
    insert_query = '''
    INSERT INTO geography_dim (
        state_territory, 
        municipality, 
        county, 
        region, 
        original_geography_type, 
        original_geography
    )
    VALUES (%s, %s, %s, %s, %s, %s)
    ON CONFLICT (original_geography) 
    DO UPDATE SET
        state_territory = EXCLUDED.state_territory,
        municipality = EXCLUDED.municipality,
        county = EXCLUDED.county,
        region = EXCLUDED.region,
        original_geography_type = EXCLUDED.original_geography_type;
    '''
    for index, row in geography_dim.iterrows():
        print(row['Geography'])
        cursor.execute(insert_query, (row['state_territory'], row['municipality'], row['county'], row['region'], row['Geography Type'], row['Geography'],))
    conn.commit()
    print(f"{len(geography_dim)} records inserted into geography_dim.")

except Exception as e:
    print(f"Error occurred: {e}")
    conn.rollback()
# Out:
# Oklahoma
# Indiana
# Nebraska
# Missouri
# Illinois
# Minnesota
# Oregon
# New York
# Vermont
# Colorado
# Maryland
# Wyoming
# West Virginia
# Maine
# Alabama
# Tennessee
# Puerto Rico
# Montana
# Wisconsin
# Texas
# New Mexico
# Alaska
# Virginia
# NY-Rest of state
# Kentucky
# District of Columbia
# Massachusetts
# Michigan
# Pennsylvania
# North Dakota
# Florida
# New Hampshire
# Ohio
# Arizona
# Rhode Island
# North Carolina
# Hawaii
# Iowa
# Kansas
# Connecticut
# Georgia
# Delaware
# Louisiana
# Commonwealth of the Northern Mariana Islands
# South Dakota
# Washington
# Utah
# New Jersey
# Mississippi
# NY-City of New York
# Arkansas
# 51 records inserted into geography_dim.

# %%
cursor.execute("SELECT geography_id, original_geography, original_geography_type FROM geography_dim")
mapping_data = cursor.fetchall()

geography_mapping = pd.DataFrame(mapping_data, columns=["geography_id", "original_geography", "original_geography_type"])
geography_mapping
# Out:
#     geography_id original_geography original_geography_type
# 0              4           Region 7    HHS Regions/National
# 1              7           Region 1    HHS Regions/National
# 2              8           Region 8    HHS Regions/National
# 3              3          Region 10    HHS Regions/National
# 4              1           Region 6    HHS Regions/National
# ..           ...                ...                     ...
# 75            55           Maryland      States/Local Areas
# 76            58   NY-Rest of state      States/Local Areas
# 77            12       North Dakota      States/Local Areas
# 78            77   TX-Dallas County      States/Local Areas
# 79            76  TX-El Paso County      States/Local Areas
#
# [80 rows x 3 columns]

# %%
# we merge df_women with the geography_mapping
df_women = pd.merge(df_women, geography_mapping, left_on = ['Geography', 'Geography Type'], right_on=['original_geography', 'original_geography_type'], how='left')
df_women.head()
# Out:
#        Geography Type Geography  Survey Year/Influenza Season  \
# 0  States/Local Areas  Oklahoma                          2021
# 1  States/Local Areas  Oklahoma                          2021
# 2  States/Local Areas  Oklahoma                          2021
# 3  States/Local Areas  Oklahoma                          2021
# 4  States/Local Areas  Oklahoma                          2021
#
#        Dimension Type                              Dimension Estimate (%)  \
# 0  Race and Ethnicity                    White, Non-Hispanic         45.2
# 1  Race and Ethnicity                    Black, Non-Hispanic         34.1
# 2  Race and Ethnicity                               Hispanic         53.4
# 3  Race and Ethnicity  Other or Multiple Races, Non-Hispanic         51.0
# 4  Race and Ethnicity                    White, Non-Hispanic         64.9
#
#      95% CI (%)  Sample Size  ci_lower  ci_upper  vaccine_id  dose_id  \
# 0  38.5 to 52.0          232      38.5      52.0          21        6
# 1  28.7 to 39.8          299      28.7      39.8          21        6
# 2  48.2 to 58.5          378      48.2      58.5          21        6
# 3  45.2 to 56.8          501      45.2      56.8          21        6
# 4  57.9 to 71.4          220      57.9      71.4          26        6
#
#    geography_id original_geography original_geography_type
# 0            30           Oklahoma      States/Local Areas
# 1            30           Oklahoma      States/Local Areas
# 2            30           Oklahoma      States/Local Areas
# 3            30           Oklahoma      States/Local Areas
# 4            30           Oklahoma      States/Local Areas

# %%
df_women[df_women['Geography'] == 'Commonwealth of the Northern Mariana Islands']
# Out:
#           Geography Type                                     Geography  \
# 2958  States/Local Areas  Commonwealth of the Northern Mariana Islands
# 2959  States/Local Areas  Commonwealth of the Northern Mariana Islands
# 2960  States/Local Areas  Commonwealth of the Northern Mariana Islands
# 2961  States/Local Areas  Commonwealth of the Northern Mariana Islands
# 2962  States/Local Areas  Commonwealth of the Northern Mariana Islands
#
#       Survey Year/Influenza Season      Dimension Type  \
# 2958                          2022                 Age
# 2959                          2022                 Age
# 2960                          2022                 Age
# 2961                          2022                 Age
# 2962                          2022  Race and Ethnicity
#
#                                   Dimension Estimate (%)    95% CI (%)  \
# 2958                            18-24 Years         83.5  70.1 to 92.6
# 2959                            25-34 Years         85.0  76.8 to 91.2
# 2960                             >=18 Years         84.6  79.0 to 89.2
# 2961                             >=35 Years         85.1  72.9 to 93.3
# 2962  Other or Multiple Races, Non-Hispanic         85.6  80.1 to 90.1
#
#       Sample Size  ci_lower  ci_upper  vaccine_id  dose_id  geography_id  \
# 2958           49      70.1      92.6          22        6           123
# 2959          107      76.8      91.2          22        6           123
# 2960          211      79.0      89.2          22        6           123
# 2961           55      72.9      93.3          22        6           123
# 2962          207      80.1      90.1          22        6           123
#
#                                 original_geography original_geography_type
# 2958  Commonwealth of the Northern Mariana Islands      States/Local Areas
# 2959  Commonwealth of the Northern Mariana Islands      States/Local Areas
# 2960  Commonwealth of the Northern Mariana Islands      States/Local Areas
# 2961  Commonwealth of the Northern Mariana Islands      States/Local Areas
# 2962  Commonwealth of the Northern Mariana Islands      States/Local Areas

# %%
# drop original columns
df_women.drop(columns=['Geography', 'Geography Type', 'original_geography', 'original_geography_type'], inplace=True)
df_women.head()
# Out:
#    Survey Year/Influenza Season      Dimension Type  \
# 0                          2021  Race and Ethnicity
# 1                          2021  Race and Ethnicity
# 2                          2021  Race and Ethnicity
# 3                          2021  Race and Ethnicity
# 4                          2021  Race and Ethnicity
#
#                                Dimension Estimate (%)    95% CI (%)  \
# 0                    White, Non-Hispanic         45.2  38.5 to 52.0
# 1                    Black, Non-Hispanic         34.1  28.7 to 39.8
# 2                               Hispanic         53.4  48.2 to 58.5
# 3  Other or Multiple Races, Non-Hispanic         51.0  45.2 to 56.8
# 4                    White, Non-Hispanic         64.9  57.9 to 71.4
#
#    Sample Size  ci_lower  ci_upper  vaccine_id  dose_id  geography_id
# 0          232      38.5      52.0          21        6            30
# 1          299      28.7      39.8          21        6            30
# 2          378      48.2      58.5          21        6            30
# 3          501      45.2      56.8          21        6            30
# 4          220      57.9      71.4          26        6            30

# %%
check_rows(df_women)
# Out:
# Rows match!

# %% [markdown]
# Since the are two dimension types: `Age` and `Race and Ethnicity`, we can separate out the dimensions. That way, we can map the `Race and Ethnicity` dimension to `race_ethnicity` dimension table.

# %%
df_age = df_women[df_women['Dimension Type'] == 'Age']
df_race = df_women[df_women['Dimension Type'] == 'Race and Ethnicity']

print(df_age.shape[0] + df_race.shape[0])
# Out:
# 4566

# %%
df_age.head()
# Out:
#     Survey Year/Influenza Season Dimension Type    Dimension Estimate (%)  \
# 8                           2014            Age   >=18 Years         51.1
# 9                           2014            Age  18-24 Years         45.4
# 10                          2014            Age  25-34 Years         54.9
# 11                          2014            Age   >=35 Years         47.6
# 20                          2013            Age  25-34 Years         56.5
#
#       95% CI (%)  Sample Size  ci_lower  ci_upper  vaccine_id  dose_id  \
# 8   46.9 to 55.3         1798      46.9      55.3          14        6
# 9   38.0 to 53.0          516      38.0      53.0          14        6
# 10  49.4 to 60.3         1091      49.4      60.3          14        6
# 11  33.3 to 62.2          191      33.3      62.2          14        6
# 20  51.1 to 61.8         1024      51.1      61.8          13        6
#
#     geography_id
# 8             30
# 9             30
# 10            30
# 11            30
# 20            30

# %%
df_age['Dimension'].unique()
# Out:
# array(['>=18 Years', '18-24 Years', '25-34 Years', '>=35 Years'],
#       dtype=object)

# %% [markdown]
# Treat age as a varchar

# %%
df_age.rename(columns={'Dimension': 'Age'}, inplace=True)
df_age.drop(columns=['Dimension Type'], inplace=True)
df_age.head()
# Out:
# /var/folders/jq/q12_1s5j0kx30cqlm76w1m740000gn/T/ipykernel_7322/1637872384.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_age.rename(columns={'Dimension': 'Age'}, inplace=True)
# /var/folders/jq/q12_1s5j0kx30cqlm76w1m740000gn/T/ipykernel_7322/1637872384.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_age.drop(columns=['Dimension Type'], inplace=True)
#     Survey Year/Influenza Season          Age Estimate (%)    95% CI (%)  \
# 8                           2014   >=18 Years         51.1  46.9 to 55.3
# 9                           2014  18-24 Years         45.4  38.0 to 53.0
# 10                          2014  25-34 Years         54.9  49.4 to 60.3
# 11                          2014   >=35 Years         47.6  33.3 to 62.2
# 20                          2013  25-34 Years         56.5  51.1 to 61.8
#
#     Sample Size  ci_lower  ci_upper  vaccine_id  dose_id  geography_id
# 8          1798      46.9      55.3          14        6            30
# 9           516      38.0      53.0          14        6            30
# 10         1091      49.4      60.3          14        6            30
# 11          191      33.3      62.2          14        6            30
# 20         1024      51.1      61.8          13        6            30

# %%
# making sure that we don't drop any rows
print(df_age.shape[0] + df_race.shape[0])
# Out:
# 4566

# %%
cursor.execute("SELECT race_ethnicity, race_ethnicity_id FROM race_ethnicity_dim")
mapping_data = cursor.fetchall()

race_ethnicity_mapping = pd.DataFrame(mapping_data, columns=["race_ethnicity", "race_ethnicity_id"])
race_ethnicity_mapping
# Out:
#                                    race_ethnicity  race_ethnicity_id
# 0  American Indian or Alaska Native, Non-Hispanic                  5
# 1                             Asian, Non-Hispanic                  6
# 2                             White, Non-Hispanic                  2
# 3                                        Hispanic                  3
# 4           Other or Multiple Races, Non-Hispanic                  1
# 5                             Black, Non-Hispanic                  4

# %%
df_race['Dimension'].unique()
# Out:
# array(['White, Non-Hispanic', 'Black, Non-Hispanic', 'Hispanic',
#        'Other or Multiple Races, Non-Hispanic'], dtype=object)

# %%
df_race = pd.merge(df_race, race_ethnicity_mapping, left_on = ['Dimension'], right_on=['race_ethnicity'], how='left')
df_race.head()
# Out:
#    Survey Year/Influenza Season      Dimension Type  \
# 0                          2021  Race and Ethnicity
# 1                          2021  Race and Ethnicity
# 2                          2021  Race and Ethnicity
# 3                          2021  Race and Ethnicity
# 4                          2021  Race and Ethnicity
#
#                                Dimension Estimate (%)    95% CI (%)  \
# 0                    White, Non-Hispanic         45.2  38.5 to 52.0
# 1                    Black, Non-Hispanic         34.1  28.7 to 39.8
# 2                               Hispanic         53.4  48.2 to 58.5
# 3  Other or Multiple Races, Non-Hispanic         51.0  45.2 to 56.8
# 4                    White, Non-Hispanic         64.9  57.9 to 71.4
#
#    Sample Size  ci_lower  ci_upper  vaccine_id  dose_id  geography_id  \
# 0          232      38.5      52.0          21        6            30
# 1          299      28.7      39.8          21        6            30
# 2          378      48.2      58.5          21        6            30
# 3          501      45.2      56.8          21        6            30
# 4          220      57.9      71.4          26        6            30
#
#                           race_ethnicity  race_ethnicity_id
# 0                    White, Non-Hispanic                  2
# 1                    Black, Non-Hispanic                  4
# 2                               Hispanic                  3
# 3  Other or Multiple Races, Non-Hispanic                  1
# 4                    White, Non-Hispanic                  2

# %%
df_race.drop(columns=['Dimension Type', 'Dimension', 'race_ethnicity'], inplace=True)
print(df_race.shape[0])
df_race.head()
# Out:
# 2146
#    Survey Year/Influenza Season Estimate (%)    95% CI (%)  Sample Size  \
# 0                          2021         45.2  38.5 to 52.0          232
# 1                          2021         34.1  28.7 to 39.8          299
# 2                          2021         53.4  48.2 to 58.5          378
# 3                          2021         51.0  45.2 to 56.8          501
# 4                          2021         64.9  57.9 to 71.4          220
#
#    ci_lower  ci_upper  vaccine_id  dose_id  geography_id  race_ethnicity_id
# 0      38.5      52.0          21        6            30                  2
# 1      28.7      39.8          21        6            30                  4
# 2      48.2      58.5          21        6            30                  3
# 3      45.2      56.8          21        6            30                  1
# 4      57.9      71.4          26        6            30                  2

# %%
df_age.rename(columns={'Survey Year/Influenza Season':'Survey Year'}, inplace=True)
# Out:
# /var/folders/jq/q12_1s5j0kx30cqlm76w1m740000gn/T/ipykernel_7322/2362203207.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_age.rename(columns={'Survey Year/Influenza Season':'Survey Year'}, inplace=True)

# %%
#since all women, we assign the gender to 4 (Females)
df_age['gender_id'] = 4 
df_age.head()
# Out:
# /var/folders/jq/q12_1s5j0kx30cqlm76w1m740000gn/T/ipykernel_7322/1455151294.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_age['gender_id'] = 4
#     Survey Year          Age Estimate (%)    95% CI (%)  Sample Size  \
# 8          2014   >=18 Years         51.1  46.9 to 55.3         1798
# 9          2014  18-24 Years         45.4  38.0 to 53.0          516
# 10         2014  25-34 Years         54.9  49.4 to 60.3         1091
# 11         2014   >=35 Years         47.6  33.3 to 62.2          191
# 20         2013  25-34 Years         56.5  51.1 to 61.8         1024
#
#     ci_lower  ci_upper  vaccine_id  dose_id  geography_id  gender_id
# 8       46.9      55.3          14        6            30          4
# 9       38.0      53.0          14        6            30          4
# 10      49.4      60.3          14        6            30          4
# 11      33.3      62.2          14        6            30          4
# 20      51.1      61.8          13        6            30          4

# %%
df_age.shape[0]
# Out:
# 2420

# %%
df_race.shape[0]
# Out:
# 2146

# %%
df_age.columns
# Out:
# Index(['Survey Year', 'Age', 'Estimate (%)', '95% CI (%)', 'Sample Size',
#        'ci_lower', 'ci_upper', 'vaccine_id', 'dose_id', 'geography_id',
#        'gender_id'],
#       dtype='object')

# %%
df_age[df_age['Estimate (%)'] == 'NR*']
# Out:
# Empty DataFrame
# Columns: [Survey Year, Age, Estimate (%), 95% CI (%), Sample Size, ci_lower, ci_upper, vaccine_id, dose_id, geography_id, gender_id]
# Index: []

# %% [markdown]
# ### Load dataset into fact tables

# %%
try:
    insert_query = '''
    INSERT INTO vaccine_transaction_fact (
      vaccine_transaction_survey_year,
      vaccine_transaction_age,
      vaccine_transaction_estimate_pct,
      vaccine_transaction_sample_size,
      vaccine_transaction_ci_lower,
      vaccine_transaction_ci_upper,
      vaccine_transaction_vaccine_id,
      vaccine_transaction_dose_id,
      vaccine_transaction_gender_id,
      vaccine_transaction_geography_id
    )
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s);
    '''
    for index, row in df_age.iterrows():

        vaccine_id = int(row['vaccine_id']) if pd.notnull(row['vaccine_id']) else None
        dose_id = int(row['dose_id']) if pd.notnull(row['dose_id']) else None
        geography_id = int(row['geography_id']) if pd.notnull(row['geography_id']) else None
        gender_id = int(row['gender_id']) if pd.notnull(row['gender_id']) else None
    
        cursor.execute(insert_query, (
            row['Survey Year'],
            row['Age'],
            row['Estimate (%)'],
            row['Sample Size'],
            row['ci_lower'],
            row['ci_upper'],
            vaccine_id,
            dose_id,
            gender_id,
            geography_id
        ))

    conn.commit()
    print(f"{len(df_age)} records inserted into vaccine_transaction_fact.")

except Exception as e:
    print(f"Error occurred: {e}")
    traceback.print_exc(file=sys.stdout)
    conn.rollback()
# Out:
# 2420 records inserted into vaccine_transaction_fact.

# %%
df_race.columns
# Out:
# Index(['Survey Year/Influenza Season', 'Estimate (%)', '95% CI (%)',
#        'Sample Size', 'ci_lower', 'ci_upper', 'vaccine_id', 'dose_id',
#        'geography_id', 'race_ethnicity_id'],
#       dtype='object')

# %%
df_race.head()
# Out:
#    Survey Year/Influenza Season Estimate (%)    95% CI (%)  Sample Size  \
# 0                          2021         45.2  38.5 to 52.0          232
# 1                          2021         34.1  28.7 to 39.8          299
# 2                          2021         53.4  48.2 to 58.5          378
# 3                          2021         51.0  45.2 to 56.8          501
# 4                          2021         64.9  57.9 to 71.4          220
#
#    ci_lower  ci_upper  vaccine_id  dose_id  geography_id  race_ethnicity_id
# 0      38.5      52.0          21        6            30                  2
# 1      28.7      39.8          21        6            30                  4
# 2      48.2      58.5          21        6            30                  3
# 3      45.2      56.8          21        6            30                  1
# 4      57.9      71.4          26        6            30                  2

# %%
try:
    insert_query = '''
    INSERT INTO vaccine_transaction_fact (
      vaccine_transaction_survey_year,
      vaccine_transaction_estimate_pct,
      vaccine_transaction_sample_size,
      vaccine_transaction_ci_lower,
      vaccine_transaction_ci_upper,
      vaccine_transaction_vaccine_id,
      vaccine_transaction_dose_id,
      vaccine_transaction_geography_id,
      vaccine_transaction_race_ethnicity_id
    )
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s);
    '''
    for index, row in df_race.iterrows():

        vaccine_id = int(row['vaccine_id']) if pd.notnull(row['vaccine_id']) else None
        dose_id = int(row['dose_id']) if pd.notnull(row['dose_id']) else None
        geography_id = int(row['geography_id']) if pd.notnull(row['geography_id']) else None
        race_ethnicity_id = int(row['race_ethnicity_id']) if pd.notnull(row['race_ethnicity_id']) else None
    
        cursor.execute(insert_query, (
            row['Survey Year/Influenza Season'],
            row['Estimate (%)'],
            row['Sample Size'],
            row['ci_lower'],
            row['ci_upper'],
            vaccine_id,
            dose_id,
            geography_id,
            race_ethnicity_id
        ))

    conn.commit()
    print(f"{len(df_race)} records inserted into vaccine_transaction_fact.")

except Exception as e:
    print(f"Error occurred: {e}")
    traceback.print_exc(file=sys.stdout)
    conn.rollback()
# Out:
# 2146 records inserted into vaccine_transaction_fact.
